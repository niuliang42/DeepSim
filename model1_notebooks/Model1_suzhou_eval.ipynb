# %% [markdown]
# ## GPS Spoofing Detection

# %% [markdown]
# ### 1. load data and preprocess

# %%
# Load Data
import DataLoader
import os
import numpy as np
import config

A, B = DataLoader.load_image_pairs(path=config.SUZHOU_RESIZED) # or config.SWISS_RESIZED
assert A.shape[0]==B.shape[0]
n = A.shape[0]
print(A.shape, B.shape)

# Some configuration
feature_map_file_name = './mid_product/features_suzhou_res34_eval.h5'#'features_suzhou_res50.h5'
#feature_map_file_name = config.FULL_RESIZED_FEATURE
dst_file_name = './mid_product/dst_suzhou_res34_eval.npy'# 'dst_suzhou_res50.npy' 
# feature_shape = (512, 18, 26) # SWISS, resnet-18/34
feature_shape = (512, 17, 34) # SUZHOU, 1280x720, resnet-18/34
# feature_shape = (2048, 17, 34) # SUZHOU, resnet-50
# Out:
# (238, 720, 1280, 3) (238, 720, 1280, 3)

# %%
# Preprocess data by doing transformation
import torch

A = A.astype(np.float)/255.0
B = B.astype(np.float)/255.0 #.transpose(0,3,1,2)
mean = np.array([0.485, 0.456, 0.406])
std = np.array([0.229, 0.224, 0.225])
x_a = torch.from_numpy((A-mean)/std).permute(0,3,1,2).float()
x_b = torch.from_numpy((B-mean)/std).permute(0,3,1,2).float()
print(x_a.size(), x_b.size())
# Out:
# torch.Size([238, 3, 720, 1280]) torch.Size([238, 3, 720, 1280])

# %% [markdown]
# ### 2. get feature maps

# %%
import torchvision.models as models
from torch import nn

pretrained_model = models.resnet34(pretrained=True)
feature_extractor = nn.Sequential(*list(pretrained_model.children())[:-1])
feature_extractor.eval()
for param in feature_extractor.parameters():
    param.requires_grad = False

# %%
# Generate feature map and save
import h5py

def h5_save(fname, f_a, f_b):
    '''save f_a and f_b as fname'''
    with h5py.File(fname,'w') as f:
        f.create_dataset('f_a', data=f_a)
        f.create_dataset('f_b', data=f_b)
    
def h5_read(fname):
    '''read fname and return f_a and f_b'''
    with h5py.File(fname,'r') as f:
        return f['f_a'][:], f['f_b'][:]

if not os.path.exists(feature_map_file_name):
    f_a = np.zeros((n,)+feature_shape)
    f_b = np.zeros((n,)+feature_shape)
    for i in range(n):
        print( "Generating feature maps of %d / %d th pair."%(i+1, n), end='\r')
        a = feature_extractor(x_a[i:i+1,:,:,:])
        b = feature_extractor(x_b[i:i+1,:,:,:])
        f_a[i] = a.detach().numpy()
        f_b[i] = b.detach().numpy()
    h5_save(feature_map_file_name, f_a, f_b)
else:
    print("Feature maps file already exists, we just read it.")
    f_a, f_b = h5_read(feature_map_file_name)
# Out:
# Generating feature maps of 238 / 238 th pair.

# %%
# compute distance between unpaird and paired images
print("A domain feature maps size:", f_a.shape)
dst=np.zeros((n,n))
for shift in range(n):
    for idx in range(n):
        a = f_a[idx:idx+1]
        b = f_b[(idx+shift)%n:(idx+shift)%n+1]
        dst[idx,shift] = np.linalg.norm(a - b)
        print('dst(idx,shift)(%d,%d)=%f' % (idx,shift,dst[idx,shift]))
np.save(dst_file_name, dst)
# Out:
# A domain feature maps size: (238, 512, 17, 34)
# dst(idx,shift)(0,0)=837.754993
# dst(idx,shift)(1,0)=667.760908
# dst(idx,shift)(2,0)=667.614221
# dst(idx,shift)(3,0)=572.453423
# dst(idx,shift)(4,0)=603.433847
# dst(idx,shift)(5,0)=380.178424
# dst(idx,shift)(6,0)=376.791483
# dst(idx,shift)(7,0)=442.229807
# dst(idx,shift)(8,0)=991.029864
# dst(idx,shift)(9,0)=744.076118
# dst(idx,shift)(10,0)=703.996269
# dst(idx,shift)(11,0)=509.542273
# dst(idx,shift)(12,0)=502.749474
# dst(idx,shift)(13,0)=485.263448
# dst(idx,shift)(14,0)=486.449944
# dst(idx,shift)(15,0)=410.809367
# dst(idx,shift)(16,0)=398.472476
# dst(idx,shift)(17,0)=427.416766
# dst(idx,shift)(18,0)=534.341537
# dst(idx,shift)(19,0)=433.056714
# dst(idx,shift)(20,0)=530.312609
# dst(idx,shift)(21,0)=489.178560
# dst(idx,shift)(22,0)=480.751966
# dst(idx,shift)(23,0)=509.245273
# dst(idx,shift)(24,0)=446.858519
# dst(idx,shift)(25,0)=464.013487
# dst(idx,shift)(26,0)=451.420107
# dst(idx,shift)(27,0)=518.439283
# dst(idx,shift)(28,0)=481.342804
# dst(idx,shift)(29,0)=497.237136
# dst(idx,shift)(30,0)=555.919153
# dst(idx,shift)(31,0)=420.690337
# dst(idx,shift)(32,0)=443.287057
# dst(idx,shift)(33,0)=406.191760
# dst(idx,shift)(34,0)=437.857512
# dst(idx,shift)(35,0)=549.056701
# dst(idx,shift)(36,0)=482.948522
# dst(idx,shift)(37,0)=483.594008
# dst(idx,shift)(38,0)=517.447152
# dst(idx,shift)(39,0)=450.489630
# dst(idx,shift)(40,0)=476.466763
# dst(idx,shift)(41,0)=468.714126
# dst(idx,shift)(42,0)=435.052330
# dst(idx,shift)(43,0)=481.147568
# dst(idx,shift)(44,0)=501.137262
# dst(idx,shift)(45,0)=466.152793
# dst(idx,shift)(46,0)=476.979476
# dst(idx,shift)(47,0)=476.478679
# dst(idx,shift)(48,0)=541.907010
# dst(idx,shift)(49,0)=472.043594
# dst(idx,shift)(50,0)=480.749675
# dst(idx,shift)(51,0)=533.655565
# dst(idx,shift)(52,0)=469.003988
# dst(idx,shift)(53,0)=440.752204
# dst(idx,shift)(54,0)=458.116438
# dst(idx,shift)(55,0)=468.101042
# dst(idx,shift)(56,0)=520.970245
# dst(idx,shift)(57,0)=567.941186
# dst(idx,shift)(58,0)=504.966549
# dst(idx,shift)(59,0)=420.500056
# dst(idx,shift)(60,0)=483.325056
# dst(idx,shift)(61,0)=562.085026
# dst(idx,shift)(62,0)=547.697102
# dst(idx,shift)(63,0)=503.246123
# dst(idx,shift)(64,0)=467.255397
# dst(idx,shift)(65,0)=451.565871
# dst(idx,shift)(66,0)=465.932366
# dst(idx,shift)(67,0)=489.654831
# dst(idx,shift)(68,0)=469.072824
# dst(idx,shift)(69,0)=513.634395
# dst(idx,shift)(70,0)=497.992397
# dst(idx,shift)(71,0)=477.750379
# dst(idx,shift)(72,0)=600.848435
# dst(idx,shift)(73,0)=650.219252
# dst(idx,shift)(74,0)=585.586555
# dst(idx,shift)(75,0)=422.707716
# dst(idx,shift)(76,0)=614.379249
# dst(idx,shift)(77,0)=598.929951
# dst(idx,shift)(78,0)=451.665567
# dst(idx,shift)(79,0)=419.402038
# dst(idx,shift)(80,0)=476.662931
# dst(idx,shift)(81,0)=529.173515
# dst(idx,shift)(82,0)=557.923678
# dst(idx,shift)(83,0)=562.460402
# dst(idx,shift)(84,0)=571.110005
# dst(idx,shift)(85,0)=596.009911
# dst(idx,shift)(86,0)=607.559105
# dst(idx,shift)(87,0)=614.422971
# dst(idx,shift)(88,0)=567.816532
# dst(idx,shift)(89,0)=550.336710
# dst(idx,shift)(90,0)=519.548935
# dst(idx,shift)(91,0)=459.523977
# dst(idx,shift)(92,0)=425.790241
# dst(idx,shift)(93,0)=441.364915
# dst(idx,shift)(94,0)=436.234425
# dst(idx,shift)(95,0)=527.594495
# dst(idx,shift)(96,0)=558.746337
# dst(idx,shift)(97,0)=593.279736
# dst(idx,shift)(98,0)=587.035005
# dst(idx,shift)(99,0)=573.514421
# dst(idx,shift)(100,0)=572.099222
# dst(idx,shift)(101,0)=467.878076
# dst(idx,shift)(102,0)=487.858044
# dst(idx,shift)(103,0)=426.181988
# dst(idx,shift)(104,0)=422.496176
# dst(idx,shift)(105,0)=428.879948
# dst(idx,shift)(106,0)=420.548006
# dst(idx,shift)(107,0)=435.030866
# dst(idx,shift)(108,0)=489.829893
# dst(idx,shift)(109,0)=410.426028
# dst(idx,shift)(110,0)=413.642234
# dst(idx,shift)(111,0)=432.292987
# dst(idx,shift)(112,0)=426.685956
# dst(idx,shift)(113,0)=423.736579
# dst(idx,shift)(114,0)=508.125675
# dst(idx,shift)(115,0)=592.893074
# dst(idx,shift)(116,0)=569.950063
# dst(idx,shift)(117,0)=559.588389
# dst(idx,shift)(118,0)=390.271923
# dst(idx,shift)(119,0)=401.599642
# dst(idx,shift)(120,0)=463.984606
# dst(idx,shift)(121,0)=483.154792
# dst(idx,shift)(122,0)=478.059633
# dst(idx,shift)(123,0)=457.467250
# dst(idx,shift)(124,0)=579.850951
# dst(idx,shift)(125,0)=585.896608
# dst(idx,shift)(126,0)=495.258167
# dst(idx,shift)(127,0)=467.158273
# dst(idx,shift)(128,0)=423.678031
# dst(idx,shift)(129,0)=565.082889
# dst(idx,shift)(130,0)=538.271461
# dst(idx,shift)(131,0)=592.190211
# dst(idx,shift)(132,0)=419.945061
# dst(idx,shift)(133,0)=602.326024
# dst(idx,shift)(134,0)=498.973349
# dst(idx,shift)(135,0)=495.096170
# dst(idx,shift)(136,0)=538.029737
# dst(idx,shift)(137,0)=556.174161
# dst(idx,shift)(138,0)=568.792518
# dst(idx,shift)(139,0)=548.249612
# dst(idx,shift)(140,0)=443.177295
# dst(idx,shift)(141,0)=479.297106
# dst(idx,shift)(142,0)=523.898487
# dst(idx,shift)(143,0)=521.400926
# dst(idx,shift)(144,0)=487.752887
# dst(idx,shift)(145,0)=436.655957
# dst(idx,shift)(146,0)=422.036498
# dst(idx,shift)(147,0)=413.270860
# dst(idx,shift)(148,0)=438.760938
# dst(idx,shift)(149,0)=495.720285
# dst(idx,shift)(150,0)=607.033908
# dst(idx,shift)(151,0)=517.444965
# dst(idx,shift)(152,0)=439.228196
# dst(idx,shift)(153,0)=429.292531
# dst(idx,shift)(154,0)=546.692855
# dst(idx,shift)(155,0)=540.506380
# dst(idx,shift)(156,0)=476.436609
# dst(idx,shift)(157,0)=430.199411
# dst(idx,shift)(158,0)=490.302622
# dst(idx,shift)(159,0)=592.795867
# dst(idx,shift)(160,0)=520.626956
# dst(idx,shift)(161,0)=470.044366
# dst(idx,shift)(162,0)=507.521839
# dst(idx,shift)(163,0)=586.736214
# dst(idx,shift)(164,0)=510.388050
# dst(idx,shift)(165,0)=447.562535
# dst(idx,shift)(166,0)=472.724300
# dst(idx,shift)(167,0)=522.498352
# dst(idx,shift)(168,0)=467.382810
# dst(idx,shift)(169,0)=524.565900
# dst(idx,shift)(170,0)=435.374282
# dst(idx,shift)(171,0)=510.714267
# dst(idx,shift)(172,0)=596.359646
# dst(idx,shift)(173,0)=533.316347
# dst(idx,shift)(174,0)=432.431396
# dst(idx,shift)(175,0)=431.500870
# dst(idx,shift)(176,0)=425.054411
# dst(idx,shift)(177,0)=490.538011
# dst(idx,shift)(178,0)=454.619271
# dst(idx,shift)(179,0)=429.611776
# dst(idx,shift)(180,0)=525.752317
# dst(idx,shift)(181,0)=540.292309
# dst(idx,shift)(182,0)=547.963059
# dst(idx,shift)(183,0)=504.475274
# dst(idx,shift)(184,0)=447.586895
# dst(idx,shift)(185,0)=461.498662
# dst(idx,shift)(186,0)=592.802702
# dst(idx,shift)(187,0)=569.055456
# dst(idx,shift)(188,0)=516.707257
# dst(idx,shift)(189,0)=389.083284
# dst(idx,shift)(190,0)=432.492186
# dst(idx,shift)(191,0)=415.976034
# dst(idx,shift)(192,0)=432.299454
# dst(idx,shift)(193,0)=427.998753
# dst(idx,shift)(194,0)=513.511464
# dst(idx,shift)(195,0)=525.705408
# dst(idx,shift)(196,0)=498.589855
# dst(idx,shift)(197,0)=531.016759
# dst(idx,shift)(198,0)=432.146499
# dst(idx,shift)(199,0)=464.920249
# dst(idx,shift)(200,0)=467.013472
# dst(idx,shift)(201,0)=517.063896
# dst(idx,shift)(202,0)=481.950954
# dst(idx,shift)(203,0)=433.371724
# dst(idx,shift)(204,0)=568.393587
# dst(idx,shift)(205,0)=315.851481
# dst(idx,shift)(206,0)=575.963094
# dst(idx,shift)(207,0)=575.725350
# dst(idx,shift)(208,0)=601.263320
# dst(idx,shift)(209,0)=630.165148
# dst(idx,shift)(210,0)=501.651612
# dst(idx,shift)(211,0)=462.273441
# dst(idx,shift)(212,0)=455.554261
# dst(idx,shift)(213,0)=438.672828
# dst(idx,shift)(214,0)=357.425603
# dst(idx,shift)(215,0)=387.501417
# dst(idx,shift)(216,0)=367.865296
# dst(idx,shift)(217,0)=482.494595
# dst(idx,shift)(218,0)=475.078614
# dst(idx,shift)(219,0)=404.372833
# dst(idx,shift)(220,0)=367.297538
# dst(idx,shift)(221,0)=393.299772
# dst(idx,shift)(222,0)=393.853283
# dst(idx,shift)(223,0)=460.366971
# dst(idx,shift)(224,0)=488.559001
# dst(idx,shift)(225,0)=361.843906
# dst(idx,shift)(226,0)=456.536321
# dst(idx,shift)(227,0)=428.111171
# dst(idx,shift)(228,0)=412.914893
# dst(idx,shift)(229,0)=308.692420
# dst(idx,shift)(230,0)=530.871024
# dst(idx,shift)(231,0)=559.292305
# dst(idx,shift)(232,0)=614.197918
# dst(idx,shift)(233,0)=632.268123
# dst(idx,shift)(234,0)=649.690845
# dst(idx,shift)(235,0)=640.885306
# dst(idx,shift)(236,0)=525.561371
# dst(idx,shift)(237,0)=546.134568
# dst(idx,shift)(0,1)=654.984729
# dst(idx,shift)(1,1)=649.638415
# dst(idx,shift)(2,1)=634.513436
# dst(idx,shift)(3,1)=644.767661
# dst(idx,shift)(4,1)=644.512567
# dst(idx,shift)(5,1)=389.233582
# dst(idx,shift)(6,1)=432.557626
# dst(idx,shift)(7,1)=861.722806
# dst(idx,shift)(8,1)=1033.645568
# dst(idx,shift)(9,1)=857.724868
# dst(idx,shift)(10,1)=611.858355
# dst(idx,shift)(11,1)=491.773047
# dst(idx,shift)(12,1)=515.137074
# dst(idx,shift)(13,1)=476.182991
# dst(idx,shift)(14,1)=476.737475
# dst(idx,shift)(15,1)=429.641242
# dst(idx,shift)(16,1)=443.741399
# dst(idx,shift)(17,1)=529.520991
# dst(idx,shift)(18,1)=528.081383
# dst(idx,shift)(19,1)=505.580288
# dst(idx,shift)(20,1)=580.748831
# dst(idx,shift)(21,1)=534.811563
# dst(idx,shift)(22,1)=484.139741
# dst(idx,shift)(23,1)=520.832941
# dst(idx,shift)(24,1)=439.822945
# dst(idx,shift)(25,1)=487.934539
# dst(idx,shift)(26,1)=537.690969
# dst(idx,shift)(27,1)=524.418170
# dst(idx,shift)(28,1)=545.886331
# dst(idx,shift)(29,1)=529.825913
# dst(idx,shift)(30,1)=543.173544
# dst(idx,shift)(31,1)=469.568170
# dst(idx,shift)(32,1)=456.531531
# dst(idx,shift)(33,1)=429.292764
# dst(idx,shift)(34,1)=555.023254
# dst(idx,shift)(35,1)=539.413515
# dst(idx,shift)(36,1)=521.699522
# dst(idx,shift)(37,1)=522.030683
# dst(idx,shift)(38,1)=543.231928
# dst(idx,shift)(39,1)=503.132773
# dst(idx,shift)(40,1)=496.309902
# dst(idx,shift)(41,1)=478.223214
# dst(idx,shift)(42,1)=497.095071
# dst(idx,shift)(43,1)=508.437993
# dst(idx,shift)(44,1)=492.772625
# dst(idx,shift)(45,1)=514.845600
# dst(idx,shift)(46,1)=525.357617
# dst(idx,shift)(47,1)=536.546222
# dst(idx,shift)(48,1)=564.889111
# dst(idx,shift)(49,1)=552.084833
# dst(idx,shift)(50,1)=582.667435
# dst(idx,shift)(51,1)=568.795832
# dst(idx,shift)(52,1)=538.505383
# dst(idx,shift)(53,1)=523.045886
# dst(idx,shift)(54,1)=515.462559
# dst(idx,shift)(55,1)=543.346365
# dst(idx,shift)(56,1)=566.822237
# dst(idx,shift)(57,1)=597.509268
# dst(idx,shift)(58,1)=528.488895
# dst(idx,shift)(59,1)=516.706564
# dst(idx,shift)(60,1)=586.478055
# dst(idx,shift)(61,1)=647.396066
# dst(idx,shift)(62,1)=598.902735
# dst(idx,shift)(63,1)=580.456087
# dst(idx,shift)(64,1)=526.427641
# dst(idx,shift)(65,1)=504.090006
# dst(idx,shift)(66,1)=558.566735
# dst(idx,shift)(67,1)=565.029313
# dst(idx,shift)(68,1)=509.681639
# dst(idx,shift)(69,1)=559.178068
# dst(idx,shift)(70,1)=550.871030
# dst(idx,shift)(71,1)=569.914264
# dst(idx,shift)(72,1)=657.216220
# dst(idx,shift)(73,1)=635.136222
# dst(idx,shift)(74,1)=618.491822
# dst(idx,shift)(75,1)=605.436532
# dst(idx,shift)(76,1)=639.774323
# dst(idx,shift)(77,1)=595.488935
# dst(idx,shift)(78,1)=468.943095
# dst(idx,shift)(79,1)=485.351644
# dst(idx,shift)(80,1)=585.331213
# dst(idx,shift)(81,1)=565.690805
# dst(idx,shift)(82,1)=613.693274
# dst(idx,shift)(83,1)=617.202864
# dst(idx,shift)(84,1)=644.442486
# dst(idx,shift)(85,1)=641.141704
# dst(idx,shift)(86,1)=643.066428
# dst(idx,shift)(87,1)=589.712921
# dst(idx,shift)(88,1)=587.310678
# dst(idx,shift)(89,1)=563.189085
# dst(idx,shift)(90,1)=541.336732
# dst(idx,shift)(91,1)=479.332122
# dst(idx,shift)(92,1)=482.307549
# dst(idx,shift)(93,1)=480.005350
# dst(idx,shift)(94,1)=522.071238
# dst(idx,shift)(95,1)=576.650437
# dst(idx,shift)(96,1)=662.037995
# dst(idx,shift)(97,1)=586.420181
# dst(idx,shift)(98,1)=574.559395
# dst(idx,shift)(99,1)=590.459879
# dst(idx,shift)(100,1)=575.275677
# dst(idx,shift)(101,1)=511.860637
# dst(idx,shift)(102,1)=462.059564
# dst(idx,shift)(103,1)=453.113391
# dst(idx,shift)(104,1)=439.954835
# dst(idx,shift)(105,1)=468.098599
# dst(idx,shift)(106,1)=472.436103
# dst(idx,shift)(107,1)=490.541668
# dst(idx,shift)(108,1)=523.961950
# dst(idx,shift)(109,1)=455.016103
# dst(idx,shift)(110,1)=451.695518
# dst(idx,shift)(111,1)=460.136002
# dst(idx,shift)(112,1)=441.069650
# dst(idx,shift)(113,1)=478.518244
# dst(idx,shift)(114,1)=615.063400
# dst(idx,shift)(115,1)=631.762396
# dst(idx,shift)(116,1)=660.664965
# dst(idx,shift)(117,1)=499.019147
# dst(idx,shift)(118,1)=426.622811
# dst(idx,shift)(119,1)=486.279886
# dst(idx,shift)(120,1)=525.178900
# dst(idx,shift)(121,1)=520.033732
# dst(idx,shift)(122,1)=503.888111
# dst(idx,shift)(123,1)=611.048246
# dst(idx,shift)(124,1)=617.214296
# dst(idx,shift)(125,1)=595.970483
# dst(idx,shift)(126,1)=561.533704
# dst(idx,shift)(127,1)=502.901888
# dst(idx,shift)(128,1)=595.811415
# dst(idx,shift)(129,1)=597.200069
# dst(idx,shift)(130,1)=586.897291
# dst(idx,shift)(131,1)=644.864589
# dst(idx,shift)(132,1)=610.936995
# dst(idx,shift)(133,1)=583.261352
# dst(idx,shift)(134,1)=517.878815
# dst(idx,shift)(135,1)=545.051943
# dst(idx,shift)(136,1)=573.385179
# dst(idx,shift)(137,1)=572.163505
# dst(idx,shift)(138,1)=610.071537
# dst(idx,shift)(139,1)=584.279013
# dst(idx,shift)(140,1)=501.246664
# dst(idx,shift)(141,1)=527.167243
# dst(idx,shift)(142,1)=584.321947
# dst(idx,shift)(143,1)=586.768213
# dst(idx,shift)(144,1)=538.127627
# dst(idx,shift)(145,1)=484.828783
# dst(idx,shift)(146,1)=509.112442
# dst(idx,shift)(147,1)=471.702869
# dst(idx,shift)(148,1)=521.682800
# dst(idx,shift)(149,1)=587.013856
# dst(idx,shift)(150,1)=646.267969
# dst(idx,shift)(151,1)=575.794013
# dst(idx,shift)(152,1)=508.111875
# dst(idx,shift)(153,1)=553.960311
# dst(idx,shift)(154,1)=602.207808
# dst(idx,shift)(155,1)=582.928891
# dst(idx,shift)(156,1)=551.963304
# dst(idx,shift)(157,1)=469.746387
# dst(idx,shift)(158,1)=542.328057
# dst(idx,shift)(159,1)=603.976772
# dst(idx,shift)(160,1)=575.450072
# dst(idx,shift)(161,1)=501.684344
# dst(idx,shift)(162,1)=537.805515
# dst(idx,shift)(163,1)=613.393515
# dst(idx,shift)(164,1)=571.681832
# dst(idx,shift)(165,1)=524.772670
# dst(idx,shift)(166,1)=548.349516
# dst(idx,shift)(167,1)=566.912090
# dst(idx,shift)(168,1)=565.370519
# dst(idx,shift)(169,1)=532.895513
# dst(idx,shift)(170,1)=511.236201
# dst(idx,shift)(171,1)=599.118543
# dst(idx,shift)(172,1)=629.004789
# dst(idx,shift)(173,1)=568.848849
# dst(idx,shift)(174,1)=494.531514
# dst(idx,shift)(175,1)=483.813657
# dst(idx,shift)(176,1)=517.137751
# dst(idx,shift)(177,1)=552.106795
# dst(idx,shift)(178,1)=509.837637
# dst(idx,shift)(179,1)=572.175176
# dst(idx,shift)(180,1)=610.331819
# dst(idx,shift)(181,1)=609.800718
# dst(idx,shift)(182,1)=584.271368
# dst(idx,shift)(183,1)=528.328530
# dst(idx,shift)(184,1)=485.318100
# dst(idx,shift)(185,1)=579.520375
# dst(idx,shift)(186,1)=635.343849
# dst(idx,shift)(187,1)=586.534638
# dst(idx,shift)(188,1)=559.079611
# dst(idx,shift)(189,1)=449.830195
# dst(idx,shift)(190,1)=468.259768
# dst(idx,shift)(191,1)=475.635452
# dst(idx,shift)(192,1)=518.035594
# dst(idx,shift)(193,1)=534.190237
# dst(idx,shift)(194,1)=609.441120
# dst(idx,shift)(195,1)=563.528135
# dst(idx,shift)(196,1)=553.052528
# dst(idx,shift)(197,1)=539.932297
# dst(idx,shift)(198,1)=498.998990
# dst(idx,shift)(199,1)=519.925925
# dst(idx,shift)(200,1)=534.318607
# dst(idx,shift)(201,1)=543.861153
# dst(idx,shift)(202,1)=522.024013
# dst(idx,shift)(203,1)=590.667289
# dst(idx,shift)(204,1)=560.979346
# dst(idx,shift)(205,1)=537.575972
# dst(idx,shift)(206,1)=606.129107
# dst(idx,shift)(207,1)=604.289537
# dst(idx,shift)(208,1)=636.188019
# dst(idx,shift)(209,1)=601.032789
# dst(idx,shift)(210,1)=517.879664
# dst(idx,shift)(211,1)=477.682506
# dst(idx,shift)(212,1)=494.185997
# dst(idx,shift)(213,1)=467.901443
# dst(idx,shift)(214,1)=408.337391
# dst(idx,shift)(215,1)=404.926889
# dst(idx,shift)(216,1)=492.260147
# dst(idx,shift)(217,1)=514.243305
# dst(idx,shift)(218,1)=532.840142
# dst(idx,shift)(219,1)=450.073835
# dst(idx,shift)(220,1)=416.884588
# dst(idx,shift)(221,1)=443.299900
# dst(idx,shift)(222,1)=468.596854
# dst(idx,shift)(223,1)=526.702513
# dst(idx,shift)(224,1)=514.177559
# dst(idx,shift)(225,1)=474.419336
# dst(idx,shift)(226,1)=506.738196
# dst(idx,shift)(227,1)=470.530468
# dst(idx,shift)(228,1)=471.142289
# dst(idx,shift)(229,1)=514.993910
# dst(idx,shift)(230,1)=599.022538
# dst(idx,shift)(231,1)=617.759439
# dst(idx,shift)(232,1)=645.295405
# dst(idx,shift)(233,1)=642.059523
# dst(idx,shift)(234,1)=678.903350
# dst(idx,shift)(235,1)=601.645212
# dst(idx,shift)(236,1)=527.036391
# dst(idx,shift)(237,1)=829.632162
# dst(idx,shift)(0,2)=638.091206
# dst(idx,shift)(1,2)=621.066430
# dst(idx,shift)(2,2)=683.649307
# dst(idx,shift)(3,2)=637.464498
# dst(idx,shift)(4,2)=633.957810
# dst(idx,shift)(5,2)=440.597249
# dst(idx,shift)(6,2)=865.414479
# dst(idx,shift)(7,2)=519.089417
# dst(idx,shift)(8,2)=1027.427298
# dst(idx,shift)(9,2)=741.634812
# dst(idx,shift)(10,2)=603.740217
# dst(idx,shift)(11,2)=526.676530
# dst(idx,shift)(12,2)=513.679372
# dst(idx,shift)(13,2)=473.781184
# dst(idx,shift)(14,2)=462.136518
# dst(idx,shift)(15,2)=453.239641
# dst(idx,shift)(16,2)=499.675019
# dst(idx,shift)(17,2)=486.481295
# dst(idx,shift)(18,2)=561.237835
# dst(idx,shift)(19,2)=510.152918
# dst(idx,shift)(20,2)=554.711000
# dst(idx,shift)(21,2)=544.744024
# dst(idx,shift)(22,2)=506.735132
# dst(idx,shift)(23,2)=507.003294
# dst(idx,shift)(24,2)=480.521088
# dst(idx,shift)(25,2)=537.404165
# dst(idx,shift)(26,2)=512.169763
# dst(idx,shift)(27,2)=564.191912
# dst(idx,shift)(28,2)=544.281193
# dst(idx,shift)(29,2)=493.862687
# dst(idx,shift)(30,2)=536.597708
# dst(idx,shift)(31,2)=441.228352
# dst(idx,shift)(32,2)=451.262635
# dst(idx,shift)(33,2)=531.434154
# dst(idx,shift)(34,2)=508.365362
# dst(idx,shift)(35,2)=522.144026
# dst(idx,shift)(36,2)=522.963796
# dst(idx,shift)(37,2)=524.203940
# dst(idx,shift)(38,2)=565.674006
# dst(idx,shift)(39,2)=507.942589
# dst(idx,shift)(40,2)=494.999829
# dst(idx,shift)(41,2)=486.165114
# dst(idx,shift)(42,2)=505.190805
# dst(idx,shift)(43,2)=501.459862
# dst(idx,shift)(44,2)=519.501350
# dst(idx,shift)(45,2)=533.124442
# dst(idx,shift)(46,2)=540.754205
# dst(idx,shift)(47,2)=496.676413
# dst(idx,shift)(48,2)=558.755801
# dst(idx,shift)(49,2)=613.294770
# dst(idx,shift)(50,2)=574.944869
# dst(idx,shift)(51,2)=588.666238
# dst(idx,shift)(52,2)=543.804362
# dst(idx,shift)(53,2)=491.494854
# dst(idx,shift)(54,2)=544.408424
# dst(idx,shift)(55,2)=552.382653
# dst(idx,shift)(56,2)=565.868148
# dst(idx,shift)(57,2)=594.835491
# dst(idx,shift)(58,2)=547.526227
# dst(idx,shift)(59,2)=571.064078
# dst(idx,shift)(60,2)=591.169091
# dst(idx,shift)(61,2)=598.189849
# dst(idx,shift)(62,2)=579.724987
# dst(idx,shift)(63,2)=573.234539
# dst(idx,shift)(64,2)=537.541516
# dst(idx,shift)(65,2)=572.596730
# dst(idx,shift)(66,2)=559.794977
# dst(idx,shift)(67,2)=526.870208
# dst(idx,shift)(68,2)=524.404095
# dst(idx,shift)(69,2)=568.206886
# dst(idx,shift)(70,2)=600.982146
# dst(idx,shift)(71,2)=592.577720
# dst(idx,shift)(72,2)=601.523822
# dst(idx,shift)(73,2)=642.274953
# dst(idx,shift)(74,2)=620.576201
# dst(idx,shift)(75,2)=648.625140
# dst(idx,shift)(76,2)=622.164994
# dst(idx,shift)(77,2)=581.617498
# dst(idx,shift)(78,2)=498.396480
# dst(idx,shift)(79,2)=556.076249
# dst(idx,shift)(80,2)=592.146595
# dst(idx,shift)(81,2)=602.121456
# dst(idx,shift)(82,2)=601.129889
# dst(idx,shift)(83,2)=651.049414
# dst(idx,shift)(84,2)=678.268646
# dst(idx,shift)(85,2)=654.891459
# dst(idx,shift)(86,2)=592.327211
# dst(idx,shift)(87,2)=598.310978
# dst(idx,shift)(88,2)=587.795460
# dst(idx,shift)(89,2)=550.961568
# dst(idx,shift)(90,2)=566.078858
# dst(idx,shift)(91,2)=508.230152
# dst(idx,shift)(92,2)=484.553278
# dst(idx,shift)(93,2)=544.875682
# dst(idx,shift)(94,2)=544.998014
# dst(idx,shift)(95,2)=660.493900
# dst(idx,shift)(96,2)=644.490901
# dst(idx,shift)(97,2)=575.407772
# dst(idx,shift)(98,2)=587.401269
# dst(idx,shift)(99,2)=577.992862
# dst(idx,shift)(100,2)=587.614043
# dst(idx,shift)(101,2)=485.705182
# dst(idx,shift)(102,2)=489.006963
# dst(idx,shift)(103,2)=458.000407
# dst(idx,shift)(104,2)=464.782343
# dst(idx,shift)(105,2)=484.145433
# dst(idx,shift)(106,2)=496.843701
# dst(idx,shift)(107,2)=485.167688
# dst(idx,shift)(108,2)=545.905392
# dst(idx,shift)(109,2)=476.407877
# dst(idx,shift)(110,2)=466.679600
# dst(idx,shift)(111,2)=469.105229
# dst(idx,shift)(112,2)=477.200233
# dst(idx,shift)(113,2)=561.567033
# dst(idx,shift)(114,2)=609.555897
# dst(idx,shift)(115,2)=667.062602
# dst(idx,shift)(116,2)=588.905169
# dst(idx,shift)(117,2)=505.809167
# dst(idx,shift)(118,2)=493.484713
# dst(idx,shift)(119,2)=481.217954
# dst(idx,shift)(120,2)=505.008399
# dst(idx,shift)(121,2)=510.130890
# dst(idx,shift)(122,2)=592.725739
# dst(idx,shift)(123,2)=625.005566
# dst(idx,shift)(124,2)=589.507133
# dst(idx,shift)(125,2)=599.394665
# dst(idx,shift)(126,2)=545.652818
# dst(idx,shift)(127,2)=620.994889
# dst(idx,shift)(128,2)=597.940554
# dst(idx,shift)(129,2)=611.560004
# dst(idx,shift)(130,2)=586.980729
# dst(idx,shift)(131,2)=659.054418
# dst(idx,shift)(132,2)=501.409859
# dst(idx,shift)(133,2)=587.999346
# dst(idx,shift)(134,2)=539.266353
# dst(idx,shift)(135,2)=555.816303
# dst(idx,shift)(136,2)=561.761599
# dst(idx,shift)(137,2)=596.329881
# dst(idx,shift)(138,2)=624.749705
# dst(idx,shift)(139,2)=558.505973
# dst(idx,shift)(140,2)=529.253273
# dst(idx,shift)(141,2)=547.669305
# dst(idx,shift)(142,2)=600.073230
# dst(idx,shift)(143,2)=578.210669
# dst(idx,shift)(144,2)=548.584026
# dst(idx,shift)(145,2)=506.018992
# dst(idx,shift)(146,2)=490.331480
# dst(idx,shift)(147,2)=485.992828
# dst(idx,shift)(148,2)=562.290477
# dst(idx,shift)(149,2)=585.542919
# dst(idx,shift)(150,2)=643.560530
# dst(idx,shift)(151,2)=554.046591
# dst(idx,shift)(152,2)=551.493957
# dst(idx,shift)(153,2)=533.725472
# dst(idx,shift)(154,2)=596.001361
# dst(idx,shift)(155,2)=597.263613
# dst(idx,shift)(156,2)=540.959840
# dst(idx,shift)(157,2)=501.641672
# dst(idx,shift)(158,2)=504.098438
# dst(idx,shift)(159,2)=633.496417
# dst(idx,shift)(160,2)=553.222587
# dst(idx,shift)(161,2)=508.330880
# dst(idx,shift)(162,2)=555.158056
# dst(idx,shift)(163,2)=650.450255
# dst(idx,shift)(164,2)=561.364963
# dst(idx,shift)(165,2)=542.810295
# dst(idx,shift)(166,2)=494.520113
# dst(idx,shift)(167,2)=596.873052
# dst(idx,shift)(168,2)=494.336899
# dst(idx,shift)(169,2)=580.549760
# dst(idx,shift)(170,2)=554.888389
# dst(idx,shift)(171,2)=549.339479
# dst(idx,shift)(172,2)=617.594115
# dst(idx,shift)(173,2)=561.662789
# dst(idx,shift)(174,2)=503.428121
# dst(idx,shift)(175,2)=498.322692
# dst(idx,shift)(176,2)=509.018245
# dst(idx,shift)(177,2)=533.310072
# dst(idx,shift)(178,2)=587.894345
# dst(idx,shift)(179,2)=607.037272
# dst(idx,shift)(180,2)=618.243441
# dst(idx,shift)(181,2)=610.584433
# dst(idx,shift)(182,2)=569.865155
# dst(idx,shift)(183,2)=527.586566
# dst(idx,shift)(184,2)=558.566109
# dst(idx,shift)(185,2)=572.377347
# dst(idx,shift)(186,2)=601.807775
# dst(idx,shift)(187,2)=571.622287
# dst(idx,shift)(188,2)=582.190130
# dst(idx,shift)(189,2)=440.095581
# dst(idx,shift)(190,2)=481.319219
# dst(idx,shift)(191,2)=475.337652
# dst(idx,shift)(192,2)=522.488335
# dst(idx,shift)(193,2)=554.445772
# dst(idx,shift)(194,2)=600.875496
# dst(idx,shift)(195,2)=568.802469
# dst(idx,shift)(196,2)=519.553624
# dst(idx,shift)(197,2)=555.934105
# dst(idx,shift)(198,2)=498.679067
# dst(idx,shift)(199,2)=526.419838
# dst(idx,shift)(200,2)=530.109772
# dst(idx,shift)(201,2)=549.920225
# dst(idx,shift)(202,2)=618.110223
# dst(idx,shift)(203,2)=498.175302
# dst(idx,shift)(204,2)=578.712170
# dst(idx,shift)(205,2)=578.858053
# dst(idx,shift)(206,2)=619.193824
# dst(idx,shift)(207,2)=626.352969
# dst(idx,shift)(208,2)=590.275251
# dst(idx,shift)(209,2)=617.512024
# dst(idx,shift)(210,2)=496.205902
# dst(idx,shift)(211,2)=495.144866
# dst(idx,shift)(212,2)=461.545037
# dst(idx,shift)(213,2)=463.849292
# dst(idx,shift)(214,2)=414.420965
# dst(idx,shift)(215,2)=488.878806
# dst(idx,shift)(216,2)=499.611345
# dst(idx,shift)(217,2)=521.622611
# dst(idx,shift)(218,2)=527.270806
# dst(idx,shift)(219,2)=473.714598
# dst(idx,shift)(220,2)=415.192386
# dst(idx,shift)(221,2)=483.639019
# dst(idx,shift)(222,2)=509.297348
# dst(idx,shift)(223,2)=514.040174
# dst(idx,shift)(224,2)=492.916654
# dst(idx,shift)(225,2)=441.799934
# dst(idx,shift)(226,2)=488.654139
# dst(idx,shift)(227,2)=483.366252
# dst(idx,shift)(228,2)=547.300177
# dst(idx,shift)(229,2)=569.364624
# dst(idx,shift)(230,2)=633.836386
# dst(idx,shift)(231,2)=641.131017
# dst(idx,shift)(232,2)=648.301024
# dst(idx,shift)(233,2)=660.425444
# dst(idx,shift)(234,2)=612.493897
# dst(idx,shift)(235,2)=603.080470
# dst(idx,shift)(236,2)=844.891063
# dst(idx,shift)(237,2)=590.721291
# dst(idx,shift)(0,3)=632.934829
# dst(idx,shift)(1,3)=667.929320
# dst(idx,shift)(2,3)=676.295271
# dst(idx,shift)(3,3)=636.620571
# dst(idx,shift)(4,3)=624.891949
# dst(idx,shift)(5,3)=860.814336
# dst(idx,shift)(6,3)=489.050837
# dst(idx,shift)(7,3)=768.962150
# dst(idx,shift)(8,3)=1044.155903
# dst(idx,shift)(9,3)=747.181006
# dst(idx,shift)(10,3)=632.115042
# dst(idx,shift)(11,3)=521.901020
# dst(idx,shift)(12,3)=503.488873
# dst(idx,shift)(13,3)=454.416113
# dst(idx,shift)(14,3)=483.947936
# dst(idx,shift)(15,3)=497.193800
# dst(idx,shift)(16,3)=479.684470
# dst(idx,shift)(17,3)=516.000521
# dst(idx,shift)(18,3)=544.496853
# dst(idx,shift)(19,3)=493.881477
# dst(idx,shift)(20,3)=560.877214
# dst(idx,shift)(21,3)=559.749454
# dst(idx,shift)(22,3)=490.276088
# dst(idx,shift)(23,3)=521.601180
# dst(idx,shift)(24,3)=529.934782
# dst(idx,shift)(25,3)=497.681514
# dst(idx,shift)(26,3)=533.594255
# dst(idx,shift)(27,3)=552.736607
# dst(idx,shift)(28,3)=500.294682
# dst(idx,shift)(29,3)=511.239239
# dst(idx,shift)(30,3)=538.676962
# dst(idx,shift)(31,3)=442.846594
# dst(idx,shift)(32,3)=548.363226
# dst(idx,shift)(33,3)=491.383012
# dst(idx,shift)(34,3)=522.265353
# dst(idx,shift)(35,3)=557.042072
# dst(idx,shift)(36,3)=513.183507
# dst(idx,shift)(37,3)=530.526488
# dst(idx,shift)(38,3)=573.902737
# dst(idx,shift)(39,3)=495.508723
# dst(idx,shift)(40,3)=491.205692
# dst(idx,shift)(41,3)=487.089588
# dst(idx,shift)(42,3)=491.514164
# dst(idx,shift)(43,3)=521.596811
# dst(idx,shift)(44,3)=532.693487
# dst(idx,shift)(45,3)=565.503120
# dst(idx,shift)(46,3)=514.825509
# dst(idx,shift)(47,3)=510.330272
# dst(idx,shift)(48,3)=589.694388
# dst(idx,shift)(49,3)=575.710002
# dst(idx,shift)(50,3)=552.929084
# dst(idx,shift)(51,3)=602.522916
# dst(idx,shift)(52,3)=538.868464
# dst(idx,shift)(53,3)=535.939969
# dst(idx,shift)(54,3)=546.994883
# dst(idx,shift)(55,3)=516.672740
# dst(idx,shift)(56,3)=559.515505
# dst(idx,shift)(57,3)=553.436774
# dst(idx,shift)(58,3)=607.129545
# dst(idx,shift)(59,3)=567.922360
# dst(idx,shift)(60,3)=541.482894
# dst(idx,shift)(61,3)=626.776650
# dst(idx,shift)(62,3)=605.766206
# dst(idx,shift)(63,3)=589.425865
# dst(idx,shift)(64,3)=587.596834
# dst(idx,shift)(65,3)=568.177265
# dst(idx,shift)(66,3)=536.905589
# dst(idx,shift)(67,3)=512.665555
# dst(idx,shift)(68,3)=540.122616
# dst(idx,shift)(69,3)=639.912384
# dst(idx,shift)(70,3)=620.849489
# dst(idx,shift)(71,3)=536.274986
# dst(idx,shift)(72,3)=616.744029
# dst(idx,shift)(73,3)=651.269339
# dst(idx,shift)(74,3)=645.702320
# dst(idx,shift)(75,3)=461.835238
# dst(idx,shift)(76,3)=613.156816
# dst(idx,shift)(77,3)=582.686022
# dst(idx,shift)(78,3)=579.308503
# dst(idx,shift)(79,3)=568.598873
# dst(idx,shift)(80,3)=593.998950
# dst(idx,shift)(81,3)=579.989265
# dst(idx,shift)(82,3)=629.486338
# dst(idx,shift)(83,3)=681.535892
# dst(idx,shift)(84,3)=690.331676
# dst(idx,shift)(85,3)=599.761419
# dst(idx,shift)(86,3)=601.396598
# dst(idx,shift)(87,3)=586.545280
# dst(idx,shift)(88,3)=572.264731
# dst(idx,shift)(89,3)=563.420555
# dst(idx,shift)(90,3)=558.611926
# dst(idx,shift)(91,3)=507.218817
# dst(idx,shift)(92,3)=534.331347
# dst(idx,shift)(93,3)=561.085607
# dst(idx,shift)(94,3)=646.685035
# dst(idx,shift)(95,3)=626.578780
# dst(idx,shift)(96,3)=624.496529
# dst(idx,shift)(97,3)=585.482127
# dst(idx,shift)(98,3)=562.483454
# dst(idx,shift)(99,3)=596.200045
# dst(idx,shift)(100,3)=562.175777
# dst(idx,shift)(101,3)=509.784288
# dst(idx,shift)(102,3)=492.911939
# dst(idx,shift)(103,3)=463.607945
# dst(idx,shift)(104,3)=469.866476
# dst(idx,shift)(105,3)=509.934335
# dst(idx,shift)(106,3)=465.003486
# dst(idx,shift)(107,3)=487.680485
# dst(idx,shift)(108,3)=559.369172
# dst(idx,shift)(109,3)=491.251826
# dst(idx,shift)(110,3)=475.299587
# dst(idx,shift)(111,3)=486.551761
# dst(idx,shift)(112,3)=566.508653
# dst(idx,shift)(113,3)=553.059514
# dst(idx,shift)(114,3)=649.900592
# dst(idx,shift)(115,3)=621.191207
# dst(idx,shift)(116,3)=607.380505
# dst(idx,shift)(117,3)=505.641314
# dst(idx,shift)(118,3)=495.635003
# dst(idx,shift)(119,3)=469.675394
# dst(idx,shift)(120,3)=498.059459
# dst(idx,shift)(121,3)=600.258859
# dst(idx,shift)(122,3)=610.931330
# dst(idx,shift)(123,3)=541.328200
# dst(idx,shift)(124,3)=570.402813
# dst(idx,shift)(125,3)=563.667396
# dst(idx,shift)(126,3)=616.642883
# dst(idx,shift)(127,3)=625.115573
# dst(idx,shift)(128,3)=605.899136
# dst(idx,shift)(129,3)=561.694249
# dst(idx,shift)(130,3)=617.589913
# dst(idx,shift)(131,3)=612.812180
# dst(idx,shift)(132,3)=506.930238
# dst(idx,shift)(133,3)=581.451339
# dst(idx,shift)(134,3)=548.375578
# dst(idx,shift)(135,3)=543.698200
# dst(idx,shift)(136,3)=566.329882
# dst(idx,shift)(137,3)=606.143263
# dst(idx,shift)(138,3)=597.463911
# dst(idx,shift)(139,3)=581.018740
# dst(idx,shift)(140,3)=524.295502
# dst(idx,shift)(141,3)=565.037234
# dst(idx,shift)(142,3)=597.093999
# dst(idx,shift)(143,3)=574.063954
# dst(idx,shift)(144,3)=536.676075
# dst(idx,shift)(145,3)=501.953403
# dst(idx,shift)(146,3)=489.356435
# dst(idx,shift)(147,3)=554.483648
# dst(idx,shift)(148,3)=547.585895
# dst(idx,shift)(149,3)=567.352711
# dst(idx,shift)(150,3)=643.406372
# dst(idx,shift)(151,3)=563.220868
# dst(idx,shift)(152,3)=518.419506
# dst(idx,shift)(153,3)=537.297253
# dst(idx,shift)(154,3)=600.864616
# dst(idx,shift)(155,3)=597.753609
# dst(idx,shift)(156,3)=545.575410
# dst(idx,shift)(157,3)=459.993764
# dst(idx,shift)(158,3)=521.004502
# dst(idx,shift)(159,3)=622.150557
# dst(idx,shift)(160,3)=556.957283
# dst(idx,shift)(161,3)=496.869274
# dst(idx,shift)(162,3)=572.053495
# dst(idx,shift)(163,3)=633.118035
# dst(idx,shift)(164,3)=587.492974
# dst(idx,shift)(165,3)=517.329114
# dst(idx,shift)(166,3)=555.431004
# dst(idx,shift)(167,3)=576.443678
# dst(idx,shift)(168,3)=544.571670
# dst(idx,shift)(169,3)=580.532630
# dst(idx,shift)(170,3)=519.554744
# dst(idx,shift)(171,3)=523.288317
# dst(idx,shift)(172,3)=598.870221
# dst(idx,shift)(173,3)=568.328589
# dst(idx,shift)(174,3)=520.554051
# dst(idx,shift)(175,3)=497.252752
# dst(idx,shift)(176,3)=470.146817
# dst(idx,shift)(177,3)=612.345251
# dst(idx,shift)(178,3)=604.447920
# dst(idx,shift)(179,3)=614.340282
# dst(idx,shift)(180,3)=571.348353
# dst(idx,shift)(181,3)=572.955354
# dst(idx,shift)(182,3)=563.742092
# dst(idx,shift)(183,3)=549.408354
# dst(idx,shift)(184,3)=545.756128
# dst(idx,shift)(185,3)=524.368828
# dst(idx,shift)(186,3)=620.291393
# dst(idx,shift)(187,3)=589.395321
# dst(idx,shift)(188,3)=567.558097
# dst(idx,shift)(189,3)=452.145693
# dst(idx,shift)(190,3)=487.305996
# dst(idx,shift)(191,3)=539.754518
# dst(idx,shift)(192,3)=561.984083
# dst(idx,shift)(193,3)=543.751350
# dst(idx,shift)(194,3)=628.524821
# dst(idx,shift)(195,3)=535.147145
# dst(idx,shift)(196,3)=532.766452
# dst(idx,shift)(197,3)=544.938205
# dst(idx,shift)(198,3)=502.225032
# dst(idx,shift)(199,3)=501.828838
# dst(idx,shift)(200,3)=520.749106
# dst(idx,shift)(201,3)=630.676284
# dst(idx,shift)(202,3)=524.250077
# dst(idx,shift)(203,3)=602.298967
# dst(idx,shift)(204,3)=608.457564
# dst(idx,shift)(205,3)=607.609270
# dst(idx,shift)(206,3)=631.585467
# dst(idx,shift)(207,3)=569.437092
# dst(idx,shift)(208,3)=609.106759
# dst(idx,shift)(209,3)=616.013362
# dst(idx,shift)(210,3)=515.764653
# dst(idx,shift)(211,3)=463.735883
# dst(idx,shift)(212,3)=476.695904
# dst(idx,shift)(213,3)=462.715676
# dst(idx,shift)(214,3)=466.386329
# dst(idx,shift)(215,3)=483.790044
# dst(idx,shift)(216,3)=421.439357
# dst(idx,shift)(217,3)=508.840671
# dst(idx,shift)(218,3)=529.650726
# dst(idx,shift)(219,3)=446.304478
# dst(idx,shift)(220,3)=467.477447
# dst(idx,shift)(221,3)=497.001592
# dst(idx,shift)(222,3)=428.137897
# dst(idx,shift)(223,3)=496.050598
# dst(idx,shift)(224,3)=500.540337
# dst(idx,shift)(225,3)=436.602444
# dst(idx,shift)(226,3)=506.191430
# dst(idx,shift)(227,3)=555.142011
# dst(idx,shift)(228,3)=572.528986
# dst(idx,shift)(229,3)=613.883048
# dst(idx,shift)(230,3)=653.822354
# dst(idx,shift)(231,3)=631.338382
# dst(idx,shift)(232,3)=661.300415
# dst(idx,shift)(233,3)=585.984472
# dst(idx,shift)(234,3)=617.909483
# dst(idx,shift)(235,3)=832.288527
# dst(idx,shift)(236,3)=579.200146
# dst(idx,shift)(237,3)=554.640672
# dst(idx,shift)(0,4)=674.785047
# dst(idx,shift)(1,4)=662.775427
# dst(idx,shift)(2,4)=670.617504
# dst(idx,shift)(3,4)=627.617515
# dst(idx,shift)(4,4)=856.079691
# dst(idx,shift)(5,4)=491.485389
# dst(idx,shift)(6,4)=758.077962
# dst(idx,shift)(7,4)=506.437922
# dst(idx,shift)(8,4)=1044.494325
# dst(idx,shift)(9,4)=768.094768
# dst(idx,shift)(10,4)=623.664456
# dst(idx,shift)(11,4)=515.164534
# dst(idx,shift)(12,4)=490.124367
# dst(idx,shift)(13,4)=478.104200
# dst(idx,shift)(14,4)=511.605546
# dst(idx,shift)(15,4)=479.127586
# dst(idx,shift)(16,4)=466.971785
# dst(idx,shift)(17,4)=537.111025
# dst(idx,shift)(18,4)=529.922327
# dst(idx,shift)(19,4)=478.680969
# dst(idx,shift)(20,4)=550.932082
# dst(idx,shift)(21,4)=536.194342
# dst(idx,shift)(22,4)=503.126104
# dst(idx,shift)(23,4)=566.998954
# dst(idx,shift)(24,4)=487.824913
# dst(idx,shift)(25,4)=515.775925
# dst(idx,shift)(26,4)=524.364318
# dst(idx,shift)(27,4)=516.448578
# dst(idx,shift)(28,4)=519.096535
# dst(idx,shift)(29,4)=500.269011
# dst(idx,shift)(30,4)=536.201653
# dst(idx,shift)(31,4)=555.034177
# dst(idx,shift)(32,4)=499.906098
# dst(idx,shift)(33,4)=490.122148
# dst(idx,shift)(34,4)=509.513839
# dst(idx,shift)(35,4)=541.488753
# dst(idx,shift)(36,4)=530.829485
# dst(idx,shift)(37,4)=539.193242
# dst(idx,shift)(38,4)=557.571904
# dst(idx,shift)(39,4)=497.873089
# dst(idx,shift)(40,4)=496.284156
# dst(idx,shift)(41,4)=481.422465
# dst(idx,shift)(42,4)=504.420426
# dst(idx,shift)(43,4)=531.463152
# dst(idx,shift)(44,4)=565.587640
# dst(idx,shift)(45,4)=497.353119
# dst(idx,shift)(46,4)=514.508846
# dst(idx,shift)(47,4)=570.665434
# dst(idx,shift)(48,4)=584.363891
# dst(idx,shift)(49,4)=553.753519
# dst(idx,shift)(50,4)=548.109822
# dst(idx,shift)(51,4)=585.333596
# dst(idx,shift)(52,4)=533.339836
# dst(idx,shift)(53,4)=547.875874
# dst(idx,shift)(54,4)=502.534702
# dst(idx,shift)(55,4)=515.411068
# dst(idx,shift)(56,4)=554.460163
# dst(idx,shift)(57,4)=616.472143
# dst(idx,shift)(58,4)=593.483136
# dst(idx,shift)(59,4)=516.752398
# dst(idx,shift)(60,4)=558.142928
# dst(idx,shift)(61,4)=624.400976
# dst(idx,shift)(62,4)=611.714254
# dst(idx,shift)(63,4)=615.113894
# dst(idx,shift)(64,4)=592.482944
# dst(idx,shift)(65,4)=533.766017
# dst(idx,shift)(66,4)=491.649636
# dst(idx,shift)(67,4)=541.698683
# dst(idx,shift)(68,4)=598.576086
# dst(idx,shift)(69,4)=651.755004
# dst(idx,shift)(70,4)=558.584054
# dst(idx,shift)(71,4)=511.868089
# dst(idx,shift)(72,4)=633.932502
# dst(idx,shift)(73,4)=658.843554
# dst(idx,shift)(74,4)=620.011052
# dst(idx,shift)(75,4)=463.891250
# dst(idx,shift)(76,4)=613.062503
# dst(idx,shift)(77,4)=624.661565
# dst(idx,shift)(78,4)=572.190085
# dst(idx,shift)(79,4)=579.058359
# dst(idx,shift)(80,4)=566.726249
# dst(idx,shift)(81,4)=617.640980
# dst(idx,shift)(82,4)=673.238183
# dst(idx,shift)(83,4)=702.318507
# dst(idx,shift)(84,4)=644.384063
# dst(idx,shift)(85,4)=610.090984
# dst(idx,shift)(86,4)=586.641472
# dst(idx,shift)(87,4)=575.079807
# dst(idx,shift)(88,4)=583.044131
# dst(idx,shift)(89,4)=573.637277
# dst(idx,shift)(90,4)=556.618852
# dst(idx,shift)(91,4)=539.618998
# dst(idx,shift)(92,4)=551.196074
# dst(idx,shift)(93,4)=672.723135
# dst(idx,shift)(94,4)=614.640531
# dst(idx,shift)(95,4)=611.150916
# dst(idx,shift)(96,4)=627.629057
# dst(idx,shift)(97,4)=539.758855
# dst(idx,shift)(98,4)=586.701601
# dst(idx,shift)(99,4)=570.851529
# dst(idx,shift)(100,4)=566.383810
# dst(idx,shift)(101,4)=502.251942
# dst(idx,shift)(102,4)=498.418753
# dst(idx,shift)(103,4)=471.852874
# dst(idx,shift)(104,4)=502.771313
# dst(idx,shift)(105,4)=452.341134
# dst(idx,shift)(106,4)=459.124696
# dst(idx,shift)(107,4)=498.938480
# dst(idx,shift)(108,4)=557.504312
# dst(idx,shift)(109,4)=484.533042
# dst(idx,shift)(110,4)=487.441192
# dst(idx,shift)(111,4)=579.449119
# dst(idx,shift)(112,4)=569.048840
# dst(idx,shift)(113,4)=583.868379
# dst(idx,shift)(114,4)=558.472811
# dst(idx,shift)(115,4)=631.002517
# dst(idx,shift)(116,4)=592.484720
# dst(idx,shift)(117,4)=521.086043
# dst(idx,shift)(118,4)=471.460856
# dst(idx,shift)(119,4)=474.124049
# dst(idx,shift)(120,4)=608.843843
# dst(idx,shift)(121,4)=634.045981
# dst(idx,shift)(122,4)=527.968261
# dst(idx,shift)(123,4)=552.683380
# dst(idx,shift)(124,4)=546.398955
# dst(idx,shift)(125,4)=630.859611
# dst(idx,shift)(126,4)=623.953651
# dst(idx,shift)(127,4)=625.041647
# dst(idx,shift)(128,4)=493.504912
# dst(idx,shift)(129,4)=593.236177
# dst(idx,shift)(130,4)=549.119234
# dst(idx,shift)(131,4)=610.995279
# dst(idx,shift)(132,4)=515.851225
# dst(idx,shift)(133,4)=583.542957
# dst(idx,shift)(134,4)=531.343453
# dst(idx,shift)(135,4)=538.081442
# dst(idx,shift)(136,4)=575.953003
# dst(idx,shift)(137,4)=592.468027
# dst(idx,shift)(138,4)=596.146553
# dst(idx,shift)(139,4)=595.688507
# dst(idx,shift)(140,4)=550.870393
# dst(idx,shift)(141,4)=552.471261
# dst(idx,shift)(142,4)=586.423298
# dst(idx,shift)(143,4)=608.795967
# dst(idx,shift)(144,4)=507.097447
# dst(idx,shift)(145,4)=480.249417
# dst(idx,shift)(146,4)=534.498028
# dst(idx,shift)(147,4)=504.654085
# dst(idx,shift)(148,4)=532.771464
# dst(idx,shift)(149,4)=552.757284
# dst(idx,shift)(150,4)=659.836325
# dst(idx,shift)(151,4)=553.491703
# dst(idx,shift)(152,4)=540.030977
# dst(idx,shift)(153,4)=525.675505
# dst(idx,shift)(154,4)=588.911030
# dst(idx,shift)(155,4)=581.818375
# dst(idx,shift)(156,4)=515.963644
# dst(idx,shift)(157,4)=456.665986
# dst(idx,shift)(158,4)=521.858111
# dst(idx,shift)(159,4)=611.776371
# dst(idx,shift)(160,4)=566.680579
# dst(idx,shift)(161,4)=524.287888
# dst(idx,shift)(162,4)=531.639565
# dst(idx,shift)(163,4)=657.825173
# dst(idx,shift)(164,4)=559.254876
# dst(idx,shift)(165,4)=536.364841
# dst(idx,shift)(166,4)=503.877004
# dst(idx,shift)(167,4)=605.024216
# dst(idx,shift)(168,4)=581.288998
# dst(idx,shift)(169,4)=568.462862
# dst(idx,shift)(170,4)=471.747006
# dst(idx,shift)(171,4)=521.238575
# dst(idx,shift)(172,4)=619.051565
# dst(idx,shift)(173,4)=561.387567
# dst(idx,shift)(174,4)=518.492418
# dst(idx,shift)(175,4)=460.754657
# dst(idx,shift)(176,4)=559.777367
# dst(idx,shift)(177,4)=621.228403
# dst(idx,shift)(178,4)=618.312492
# dst(idx,shift)(179,4)=582.918580
# dst(idx,shift)(180,4)=557.817633
# dst(idx,shift)(181,4)=558.311750
# dst(idx,shift)(182,4)=564.456161
# dst(idx,shift)(183,4)=534.659066
# dst(idx,shift)(184,4)=499.233790
# dst(idx,shift)(185,4)=506.947003
# dst(idx,shift)(186,4)=637.400906
# dst(idx,shift)(187,4)=586.416812
# dst(idx,shift)(188,4)=567.625939
# dst(idx,shift)(189,4)=462.069498
# dst(idx,shift)(190,4)=531.832363
# dst(idx,shift)(191,4)=538.920951
# dst(idx,shift)(192,4)=550.935984
# dst(idx,shift)(193,4)=563.512534
# dst(idx,shift)(194,4)=592.079633
# dst(idx,shift)(195,4)=551.230710
# dst(idx,shift)(196,4)=522.370496
# dst(idx,shift)(197,4)=547.239173
# dst(idx,shift)(198,4)=485.907577
# dst(idx,shift)(199,4)=499.155315
# dst(idx,shift)(200,4)=589.578558
# dst(idx,shift)(201,4)=542.559344
# dst(idx,shift)(202,4)=631.597850
# dst(idx,shift)(203,4)=626.301856
# dst(idx,shift)(204,4)=624.180084
# dst(idx,shift)(205,4)=614.566733
# dst(idx,shift)(206,4)=579.626339
# dst(idx,shift)(207,4)=579.728255
# dst(idx,shift)(208,4)=590.024035
# dst(idx,shift)(209,4)=602.263774
# dst(idx,shift)(210,4)=474.102928
# dst(idx,shift)(211,4)=460.546267
# dst(idx,shift)(212,4)=467.824658
# dst(idx,shift)(213,4)=514.644351
# dst(idx,shift)(214,4)=471.513838
# dst(idx,shift)(215,4)=425.056816
# dst(idx,shift)(216,4)=410.721981
# dst(idx,shift)(217,4)=512.352276
# dst(idx,shift)(218,4)=525.483180
# dst(idx,shift)(219,4)=470.108707
# dst(idx,shift)(220,4)=498.040763
# dst(idx,shift)(221,4)=410.114791
# dst(idx,shift)(222,4)=468.660632
# dst(idx,shift)(223,4)=514.337463
# dst(idx,shift)(224,4)=502.523473
# dst(idx,shift)(225,4)=462.575779
# dst(idx,shift)(226,4)=553.816837
# dst(idx,shift)(227,4)=586.561605
# dst(idx,shift)(228,4)=623.556021
# dst(idx,shift)(229,4)=643.510016
# dst(idx,shift)(230,4)=658.475491
# dst(idx,shift)(231,4)=644.784412
# dst(idx,shift)(232,4)=572.933825
# dst(idx,shift)(233,4)=589.648689
# dst(idx,shift)(234,4)=828.062639
# dst(idx,shift)(235,4)=619.694395
# dst(idx,shift)(236,4)=571.331214
# dst(idx,shift)(237,4)=546.666031
# dst(idx,shift)(0,5)=664.443214
# dst(idx,shift)(1,5)=648.119669
# dst(idx,shift)(2,5)=667.822904
# dst(idx,shift)(3,5)=860.402223
# dst(idx,shift)(4,5)=600.038086
# dst(idx,shift)(5,5)=753.572767
# dst(idx,shift)(6,5)=449.329785
# dst(idx,shift)(7,5)=488.140558
# dst(idx,shift)(8,5)=1057.700581
# dst(idx,shift)(9,5)=773.118601
# dst(idx,shift)(10,5)=627.084606
# dst(idx,shift)(11,5)=503.389524
# dst(idx,shift)(12,5)=513.200818
# dst(idx,shift)(13,5)=515.919709
# dst(idx,shift)(14,5)=509.829183
# dst(idx,shift)(15,5)=493.552062
# dst(idx,shift)(16,5)=505.516760
# dst(idx,shift)(17,5)=504.544752
# dst(idx,shift)(18,5)=543.786065
# dst(idx,shift)(19,5)=493.276366
# dst(idx,shift)(20,5)=532.940682
# dst(idx,shift)(21,5)=562.755492
# dst(idx,shift)(22,5)=536.427936
# dst(idx,shift)(23,5)=510.070252
# dst(idx,shift)(24,5)=489.910960
# dst(idx,shift)(25,5)=519.371454
# dst(idx,shift)(26,5)=496.572499
# dst(idx,shift)(27,5)=531.139025
# dst(idx,shift)(28,5)=511.337824
# dst(idx,shift)(29,5)=501.059148
# dst(idx,shift)(30,5)=585.479829
# dst(idx,shift)(31,5)=506.495393
# dst(idx,shift)(32,5)=511.412660
# dst(idx,shift)(33,5)=489.702546
# dst(idx,shift)(34,5)=487.871052
# dst(idx,shift)(35,5)=545.851967
# dst(idx,shift)(36,5)=531.404950
# dst(idx,shift)(37,5)=515.952891
# dst(idx,shift)(38,5)=549.850685
# dst(idx,shift)(39,5)=512.160107
# dst(idx,shift)(40,5)=464.293818
# dst(idx,shift)(41,5)=511.874866
# dst(idx,shift)(42,5)=506.304786
# dst(idx,shift)(43,5)=562.349134
# dst(idx,shift)(44,5)=503.105649
# dst(idx,shift)(45,5)=501.423827
# dst(idx,shift)(46,5)=584.032736
# dst(idx,shift)(47,5)=538.258045
# dst(idx,shift)(48,5)=573.718006
# dst(idx,shift)(49,5)=575.723370
# dst(idx,shift)(50,5)=564.499266
# dst(idx,shift)(51,5)=566.204207
# dst(idx,shift)(52,5)=572.395500
# dst(idx,shift)(53,5)=510.166531
# dst(idx,shift)(54,5)=484.460391
# dst(idx,shift)(55,5)=515.151184
# dst(idx,shift)(56,5)=560.271148
# dst(idx,shift)(57,5)=622.076742
# dst(idx,shift)(58,5)=569.880388
# dst(idx,shift)(59,5)=487.322211
# dst(idx,shift)(60,5)=545.862690
# dst(idx,shift)(61,5)=634.766405
# dst(idx,shift)(62,5)=615.748583
# dst(idx,shift)(63,5)=607.412063
# dst(idx,shift)(64,5)=550.806713
# dst(idx,shift)(65,5)=525.480232
# dst(idx,shift)(66,5)=503.672616
# dst(idx,shift)(67,5)=605.547114
# dst(idx,shift)(68,5)=607.799757
# dst(idx,shift)(69,5)=599.061895
# dst(idx,shift)(70,5)=544.093204
# dst(idx,shift)(71,5)=575.298880
# dst(idx,shift)(72,5)=649.729973
# dst(idx,shift)(73,5)=650.808738
# dst(idx,shift)(74,5)=610.837151
# dst(idx,shift)(75,5)=469.710888
# dst(idx,shift)(76,5)=644.450323
# dst(idx,shift)(77,5)=624.604629
# dst(idx,shift)(78,5)=587.385346
# dst(idx,shift)(79,5)=537.804764
# dst(idx,shift)(80,5)=613.895356
# dst(idx,shift)(81,5)=656.029361
# dst(idx,shift)(82,5)=684.410281
# dst(idx,shift)(83,5)=643.381723
# dst(idx,shift)(84,5)=627.712821
# dst(idx,shift)(85,5)=613.513228
# dst(idx,shift)(86,5)=581.754244
# dst(idx,shift)(87,5)=586.917987
# dst(idx,shift)(88,5)=590.766248
# dst(idx,shift)(89,5)=556.868771
# dst(idx,shift)(90,5)=594.716358
# dst(idx,shift)(91,5)=561.410235
# dst(idx,shift)(92,5)=655.396954
# dst(idx,shift)(93,5)=619.466014
# dst(idx,shift)(94,5)=587.464908
# dst(idx,shift)(95,5)=612.765658
# dst(idx,shift)(96,5)=580.196585
# dst(idx,shift)(97,5)=565.459699
# dst(idx,shift)(98,5)=554.096340
# dst(idx,shift)(99,5)=585.197070
# dst(idx,shift)(100,5)=558.713571
# dst(idx,shift)(101,5)=510.157025
# dst(idx,shift)(102,5)=505.471508
# dst(idx,shift)(103,5)=498.397262
# dst(idx,shift)(104,5)=456.894662
# dst(idx,shift)(105,5)=454.840869
# dst(idx,shift)(106,5)=470.905327
# dst(idx,shift)(107,5)=487.226937
# dst(idx,shift)(108,5)=562.181875
# dst(idx,shift)(109,5)=508.840680
# dst(idx,shift)(110,5)=589.425360
# dst(idx,shift)(111,5)=576.191060
# dst(idx,shift)(112,5)=592.202576
# dst(idx,shift)(113,5)=463.311860
# dst(idx,shift)(114,5)=568.439114
# dst(idx,shift)(115,5)=620.438644
# dst(idx,shift)(116,5)=603.122083
# dst(idx,shift)(117,5)=497.959964
# dst(idx,shift)(118,5)=472.873588
# dst(idx,shift)(119,5)=598.882529
# dst(idx,shift)(120,5)=624.239288
# dst(idx,shift)(121,5)=543.404274
# dst(idx,shift)(122,5)=527.540276
# dst(idx,shift)(123,5)=503.730318
# dst(idx,shift)(124,5)=609.681434
# dst(idx,shift)(125,5)=597.615754
# dst(idx,shift)(126,5)=620.084329
# dst(idx,shift)(127,5)=515.616250
# dst(idx,shift)(128,5)=596.791910
# dst(idx,shift)(129,5)=502.997585
# dst(idx,shift)(130,5)=542.482728
# dst(idx,shift)(131,5)=611.780938
# dst(idx,shift)(132,5)=513.413296
# dst(idx,shift)(133,5)=572.382254
# dst(idx,shift)(134,5)=532.816495
# dst(idx,shift)(135,5)=552.974914
# dst(idx,shift)(136,5)=564.292203
# dst(idx,shift)(137,5)=576.272640
# dst(idx,shift)(138,5)=612.132507
# dst(idx,shift)(139,5)=602.717486
# dst(idx,shift)(140,5)=527.595130
# dst(idx,shift)(141,5)=557.350559
# dst(idx,shift)(142,5)=609.153811
# dst(idx,shift)(143,5)=572.087284
# dst(idx,shift)(144,5)=510.309730
# dst(idx,shift)(145,5)=539.821955
# dst(idx,shift)(146,5)=510.229409
# dst(idx,shift)(147,5)=482.948868
# dst(idx,shift)(148,5)=531.643939
# dst(idx,shift)(149,5)=570.173588
# dst(idx,shift)(150,5)=639.197143
# dst(idx,shift)(151,5)=554.963041
# dst(idx,shift)(152,5)=516.631482
# dst(idx,shift)(153,5)=532.355254
# dst(idx,shift)(154,5)=602.816848
# dst(idx,shift)(155,5)=579.899435
# dst(idx,shift)(156,5)=552.634970
# dst(idx,shift)(157,5)=479.765422
# dst(idx,shift)(158,5)=548.470531
# dst(idx,shift)(159,5)=629.567922
# dst(idx,shift)(160,5)=592.494408
# dst(idx,shift)(161,5)=482.259844
# dst(idx,shift)(162,5)=555.774017
# dst(idx,shift)(163,5)=622.962271
# dst(idx,shift)(164,5)=583.612714
# dst(idx,shift)(165,5)=521.736059
# dst(idx,shift)(166,5)=546.860715
# dst(idx,shift)(167,5)=604.113720
# dst(idx,shift)(168,5)=542.089253
# dst(idx,shift)(169,5)=549.400594
# dst(idx,shift)(170,5)=488.383710
# dst(idx,shift)(171,5)=548.119517
# dst(idx,shift)(172,5)=619.976586
# dst(idx,shift)(173,5)=590.705974
# dst(idx,shift)(174,5)=497.572380
# dst(idx,shift)(175,5)=574.052508
# dst(idx,shift)(176,5)=588.801452
# dst(idx,shift)(177,5)=634.347910
# dst(idx,shift)(178,5)=587.604253
# dst(idx,shift)(179,5)=522.973031
# dst(idx,shift)(180,5)=563.679353
# dst(idx,shift)(181,5)=578.348457
# dst(idx,shift)(182,5)=558.501199
# dst(idx,shift)(183,5)=539.093971
# dst(idx,shift)(184,5)=451.162014
# dst(idx,shift)(185,5)=525.245444
# dst(idx,shift)(186,5)=625.471929
# dst(idx,shift)(187,5)=601.703114
# dst(idx,shift)(188,5)=583.479948
# dst(idx,shift)(189,5)=521.088892
# dst(idx,shift)(190,5)=549.337105
# dst(idx,shift)(191,5)=537.849119
# dst(idx,shift)(192,5)=570.128204
# dst(idx,shift)(193,5)=475.535943
# dst(idx,shift)(194,5)=569.880665
# dst(idx,shift)(195,5)=548.183741
# dst(idx,shift)(196,5)=535.038546
# dst(idx,shift)(197,5)=542.740226
# dst(idx,shift)(198,5)=466.568738
# dst(idx,shift)(199,5)=559.105643
# dst(idx,shift)(200,5)=493.127478
# dst(idx,shift)(201,5)=648.581442
# dst(idx,shift)(202,5)=633.800115
# dst(idx,shift)(203,5)=650.904112
# dst(idx,shift)(204,5)=633.917821
# dst(idx,shift)(205,5)=478.402884
# dst(idx,shift)(206,5)=598.412727
# dst(idx,shift)(207,5)=564.598407
# dst(idx,shift)(208,5)=599.258869
# dst(idx,shift)(209,5)=593.141508
# dst(idx,shift)(210,5)=500.516782
# dst(idx,shift)(211,5)=460.932554
# dst(idx,shift)(212,5)=493.274203
# dst(idx,shift)(213,5)=512.532080
# dst(idx,shift)(214,5)=431.388767
# dst(idx,shift)(215,5)=387.342646
# dst(idx,shift)(216,5)=425.986877
# dst(idx,shift)(217,5)=514.294891
# dst(idx,shift)(218,5)=521.205596
# dst(idx,shift)(219,5)=509.011974
# dst(idx,shift)(220,5)=406.199096
# dst(idx,shift)(221,5)=468.756596
# dst(idx,shift)(222,5)=445.353815
# dst(idx,shift)(223,5)=495.434585
# dst(idx,shift)(224,5)=504.071718
# dst(idx,shift)(225,5)=535.030401
# dst(idx,shift)(226,5)=583.446510
# dst(idx,shift)(227,5)=624.189136
# dst(idx,shift)(228,5)=650.343541
# dst(idx,shift)(229,5)=634.552211
# dst(idx,shift)(230,5)=653.479200
# dst(idx,shift)(231,5)=567.991014
# dst(idx,shift)(232,5)=588.641203
# dst(idx,shift)(233,5)=825.804220
# dst(idx,shift)(234,5)=625.169257
# dst(idx,shift)(235,5)=581.214785
# dst(idx,shift)(236,5)=542.433400
# dst(idx,shift)(237,5)=604.481376
# dst(idx,shift)(0,6)=651.597970
# dst(idx,shift)(1,6)=648.603157
# dst(idx,shift)(2,6)=877.910284
# dst(idx,shift)(3,6)=611.887603
# dst(idx,shift)(4,6)=788.611832
# dst(idx,shift)(5,6)=460.038919
# dst(idx,shift)(6,6)=426.744593
# dst(idx,shift)(7,6)=491.843960
# dst(idx,shift)(8,6)=1062.740907
# dst(idx,shift)(9,6)=771.401040
# dst(idx,shift)(10,6)=628.950399
# dst(idx,shift)(11,6)=508.376396
# dst(idx,shift)(12,6)=524.708939
# dst(idx,shift)(13,6)=500.160544
# dst(idx,shift)(14,6)=529.914421
# dst(idx,shift)(15,6)=491.016918
# dst(idx,shift)(16,6)=473.468542
# dst(idx,shift)(17,6)=495.036088
# dst(idx,shift)(18,6)=564.103715
# dst(idx,shift)(19,6)=470.558264
# dst(idx,shift)(20,6)=536.147420
# dst(idx,shift)(21,6)=567.198266
# dst(idx,shift)(22,6)=496.449871
# dst(idx,shift)(23,6)=548.070019
# dst(idx,shift)(24,6)=494.829893
# dst(idx,shift)(25,6)=468.623344
# dst(idx,shift)(26,6)=503.005061
# dst(idx,shift)(27,6)=524.356474
# dst(idx,shift)(28,6)=508.731667
# dst(idx,shift)(29,6)=596.743451
# dst(idx,shift)(30,6)=563.981034
# dst(idx,shift)(31,6)=510.310277
# dst(idx,shift)(32,6)=510.398352
# dst(idx,shift)(33,6)=462.671781
# dst(idx,shift)(34,6)=483.861962
# dst(idx,shift)(35,6)=562.901176
# dst(idx,shift)(36,6)=520.034921
# dst(idx,shift)(37,6)=529.266900
# dst(idx,shift)(38,6)=561.783254
# dst(idx,shift)(39,6)=494.908180
# dst(idx,shift)(40,6)=513.756536
# dst(idx,shift)(41,6)=521.650922
# dst(idx,shift)(42,6)=538.565597
# dst(idx,shift)(43,6)=513.408694
# dst(idx,shift)(44,6)=508.019269
# dst(idx,shift)(45,6)=569.807689
# ...
# dst(idx,shift)(14,236)=478.925680
# dst(idx,shift)(15,236)=470.662869
# dst(idx,shift)(16,236)=447.517668
# dst(idx,shift)(17,236)=489.334417
# dst(idx,shift)(18,236)=540.286099
# dst(idx,shift)(19,236)=470.416692
# dst(idx,shift)(20,236)=568.507625
# dst(idx,shift)(21,236)=536.365834
# dst(idx,shift)(22,236)=523.492499
# dst(idx,shift)(23,236)=546.734975
# dst(idx,shift)(24,236)=483.299784
# dst(idx,shift)(25,236)=487.229880
# dst(idx,shift)(26,236)=508.939518
# dst(idx,shift)(27,236)=530.799668
# dst(idx,shift)(28,236)=515.849589
# dst(idx,shift)(29,236)=587.077931
# dst(idx,shift)(30,236)=570.574434
# dst(idx,shift)(31,236)=479.544855
# dst(idx,shift)(32,236)=500.792940
# dst(idx,shift)(33,236)=435.532481
# dst(idx,shift)(34,236)=462.326126
# dst(idx,shift)(35,236)=539.190012
# dst(idx,shift)(36,236)=507.731231
# dst(idx,shift)(37,236)=562.842894
# dst(idx,shift)(38,236)=545.764409
# dst(idx,shift)(39,236)=527.489428
# dst(idx,shift)(40,236)=530.352261
# dst(idx,shift)(41,236)=486.917190
# dst(idx,shift)(42,236)=494.105724
# dst(idx,shift)(43,236)=512.769322
# dst(idx,shift)(44,236)=505.096751
# dst(idx,shift)(45,236)=497.033720
# dst(idx,shift)(46,236)=522.359998
# dst(idx,shift)(47,236)=528.444463
# dst(idx,shift)(48,236)=592.506871
# dst(idx,shift)(49,236)=537.821436
# dst(idx,shift)(50,236)=560.229625
# dst(idx,shift)(51,236)=571.233520
# dst(idx,shift)(52,236)=520.662522
# dst(idx,shift)(53,236)=532.830828
# dst(idx,shift)(54,236)=521.249109
# dst(idx,shift)(55,236)=494.374228
# dst(idx,shift)(56,236)=564.295579
# dst(idx,shift)(57,236)=618.649645
# dst(idx,shift)(58,236)=584.961821
# dst(idx,shift)(59,236)=534.886573
# dst(idx,shift)(60,236)=553.661717
# dst(idx,shift)(61,236)=627.505506
# dst(idx,shift)(62,236)=585.674406
# dst(idx,shift)(63,236)=593.156011
# dst(idx,shift)(64,236)=589.918839
# dst(idx,shift)(65,236)=546.258810
# dst(idx,shift)(66,236)=518.111539
# dst(idx,shift)(67,236)=543.023254
# dst(idx,shift)(68,236)=523.791917
# dst(idx,shift)(69,236)=587.193172
# dst(idx,shift)(70,236)=586.765394
# dst(idx,shift)(71,236)=529.099202
# dst(idx,shift)(72,236)=617.720752
# dst(idx,shift)(73,236)=638.280238
# dst(idx,shift)(74,236)=617.573803
# dst(idx,shift)(75,236)=577.646949
# dst(idx,shift)(76,236)=587.711386
# dst(idx,shift)(77,236)=585.443655
# dst(idx,shift)(78,236)=604.027323
# dst(idx,shift)(79,236)=640.020445
# dst(idx,shift)(80,236)=527.788853
# dst(idx,shift)(81,236)=530.607364
# dst(idx,shift)(82,236)=560.450233
# dst(idx,shift)(83,236)=656.050458
# dst(idx,shift)(84,236)=651.075491
# dst(idx,shift)(85,236)=612.342983
# dst(idx,shift)(86,236)=590.266847
# dst(idx,shift)(87,236)=601.107992
# dst(idx,shift)(88,236)=668.303358
# dst(idx,shift)(89,236)=661.539912
# dst(idx,shift)(90,236)=604.448505
# dst(idx,shift)(91,236)=551.454440
# dst(idx,shift)(92,236)=500.995015
# dst(idx,shift)(93,236)=484.547702
# dst(idx,shift)(94,236)=480.152302
# dst(idx,shift)(95,236)=557.607548
# dst(idx,shift)(96,236)=577.257091
# dst(idx,shift)(97,236)=557.537435
# dst(idx,shift)(98,236)=562.879628
# dst(idx,shift)(99,236)=647.837999
# dst(idx,shift)(100,236)=614.078537
# dst(idx,shift)(101,236)=576.797771
# dst(idx,shift)(102,236)=583.143410
# dst(idx,shift)(103,236)=482.837784
# dst(idx,shift)(104,236)=519.528562
# dst(idx,shift)(105,236)=474.507524
# dst(idx,shift)(106,236)=463.542892
# dst(idx,shift)(107,236)=483.283119
# dst(idx,shift)(108,236)=533.354763
# dst(idx,shift)(109,236)=471.742591
# dst(idx,shift)(110,236)=493.504830
# dst(idx,shift)(111,236)=457.141585
# dst(idx,shift)(112,236)=471.875190
# dst(idx,shift)(113,236)=488.161117
# dst(idx,shift)(114,236)=562.171003
# dst(idx,shift)(115,236)=622.219433
# dst(idx,shift)(116,236)=572.135618
# dst(idx,shift)(117,236)=593.724305
# dst(idx,shift)(118,236)=601.546712
# dst(idx,shift)(119,236)=590.936065
# dst(idx,shift)(120,236)=492.555895
# dst(idx,shift)(121,236)=502.164779
# dst(idx,shift)(122,236)=502.572956
# dst(idx,shift)(123,236)=524.149129
# dst(idx,shift)(124,236)=537.172125
# dst(idx,shift)(125,236)=565.863084
# dst(idx,shift)(126,236)=619.176475
# dst(idx,shift)(127,236)=624.766948
# dst(idx,shift)(128,236)=523.031966
# dst(idx,shift)(129,236)=592.869176
# dst(idx,shift)(130,236)=563.375718
# dst(idx,shift)(131,236)=652.219787
# dst(idx,shift)(132,236)=608.567899
# dst(idx,shift)(133,236)=617.503419
# dst(idx,shift)(134,236)=565.974271
# dst(idx,shift)(135,236)=656.130948
# dst(idx,shift)(136,236)=556.840092
# dst(idx,shift)(137,236)=578.620128
# dst(idx,shift)(138,236)=611.036669
# dst(idx,shift)(139,236)=586.585140
# dst(idx,shift)(140,236)=514.380794
# dst(idx,shift)(141,236)=506.927351
# dst(idx,shift)(142,236)=596.910877
# dst(idx,shift)(143,236)=590.021595
# dst(idx,shift)(144,236)=530.466763
# dst(idx,shift)(145,236)=478.274410
# dst(idx,shift)(146,236)=543.657890
# dst(idx,shift)(147,236)=486.278681
# dst(idx,shift)(148,236)=525.553748
# dst(idx,shift)(149,236)=578.367503
# dst(idx,shift)(150,236)=640.514412
# dst(idx,shift)(151,236)=550.454145
# dst(idx,shift)(152,236)=562.740280
# dst(idx,shift)(153,236)=539.200831
# dst(idx,shift)(154,236)=607.572165
# dst(idx,shift)(155,236)=576.284474
# dst(idx,shift)(156,236)=562.864798
# dst(idx,shift)(157,236)=481.229847
# dst(idx,shift)(158,236)=537.876237
# dst(idx,shift)(159,236)=630.462384
# dst(idx,shift)(160,236)=555.575787
# dst(idx,shift)(161,236)=512.834912
# dst(idx,shift)(162,236)=509.873807
# dst(idx,shift)(163,236)=644.169750
# dst(idx,shift)(164,236)=570.853193
# dst(idx,shift)(165,236)=553.623242
# dst(idx,shift)(166,236)=512.786826
# dst(idx,shift)(167,236)=601.379788
# dst(idx,shift)(168,236)=506.411188
# dst(idx,shift)(169,236)=564.754593
# dst(idx,shift)(170,236)=470.823603
# dst(idx,shift)(171,236)=567.039204
# dst(idx,shift)(172,236)=609.340328
# dst(idx,shift)(173,236)=587.084186
# dst(idx,shift)(174,236)=574.326103
# dst(idx,shift)(175,236)=499.126395
# dst(idx,shift)(176,236)=477.628568
# dst(idx,shift)(177,236)=541.300004
# dst(idx,shift)(178,236)=516.302877
# dst(idx,shift)(179,236)=525.652194
# dst(idx,shift)(180,236)=529.138108
# dst(idx,shift)(181,236)=548.920688
# dst(idx,shift)(182,236)=582.821081
# dst(idx,shift)(183,236)=614.263929
# dst(idx,shift)(184,236)=610.798363
# dst(idx,shift)(185,236)=596.032204
# dst(idx,shift)(186,236)=645.735282
# dst(idx,shift)(187,236)=589.774723
# dst(idx,shift)(188,236)=588.593177
# dst(idx,shift)(189,236)=560.955692
# dst(idx,shift)(190,236)=509.391267
# dst(idx,shift)(191,236)=451.736168
# dst(idx,shift)(192,236)=509.479910
# dst(idx,shift)(193,236)=451.117899
# dst(idx,shift)(194,236)=563.454855
# dst(idx,shift)(195,236)=543.252063
# dst(idx,shift)(196,236)=552.881148
# dst(idx,shift)(197,236)=568.984684
# dst(idx,shift)(198,236)=534.724786
# dst(idx,shift)(199,236)=560.414248
# dst(idx,shift)(200,236)=508.803776
# dst(idx,shift)(201,236)=569.305193
# dst(idx,shift)(202,236)=538.259695
# dst(idx,shift)(203,236)=521.897640
# dst(idx,shift)(204,236)=575.912276
# dst(idx,shift)(205,236)=427.503467
# dst(idx,shift)(206,236)=589.135542
# dst(idx,shift)(207,236)=565.538342
# dst(idx,shift)(208,236)=619.529595
# dst(idx,shift)(209,236)=625.998210
# dst(idx,shift)(210,236)=608.602626
# dst(idx,shift)(211,236)=613.745557
# dst(idx,shift)(212,236)=508.103583
# dst(idx,shift)(213,236)=508.258097
# dst(idx,shift)(214,236)=440.941168
# dst(idx,shift)(215,236)=451.690195
# dst(idx,shift)(216,236)=422.829759
# dst(idx,shift)(217,236)=518.625286
# dst(idx,shift)(218,236)=536.472682
# dst(idx,shift)(219,236)=490.884661
# dst(idx,shift)(220,236)=485.822775
# dst(idx,shift)(221,236)=448.487760
# dst(idx,shift)(222,236)=421.190921
# dst(idx,shift)(223,236)=509.339839
# dst(idx,shift)(224,236)=509.748104
# dst(idx,shift)(225,236)=478.270756
# dst(idx,shift)(226,236)=514.246641
# dst(idx,shift)(227,236)=487.386472
# dst(idx,shift)(228,236)=474.864825
# dst(idx,shift)(229,236)=440.848058
# dst(idx,shift)(230,236)=551.569022
# dst(idx,shift)(231,236)=540.484583
# dst(idx,shift)(232,236)=573.243536
# dst(idx,shift)(233,236)=593.095479
# dst(idx,shift)(234,236)=632.352941
# dst(idx,shift)(235,236)=662.336792
# dst(idx,shift)(236,236)=648.160828
# dst(idx,shift)(237,236)=660.751723
# dst(idx,shift)(0,237)=655.687693
# dst(idx,shift)(1,237)=894.903402
# dst(idx,shift)(2,237)=692.532710
# dst(idx,shift)(3,237)=621.334443
# dst(idx,shift)(4,237)=603.567519
# dst(idx,shift)(5,237)=541.594711
# dst(idx,shift)(6,237)=430.928433
# dst(idx,shift)(7,237)=496.113552
# dst(idx,shift)(8,237)=1060.298369
# dst(idx,shift)(9,237)=877.261797
# dst(idx,shift)(10,237)=579.502678
# dst(idx,shift)(11,237)=775.074958
# dst(idx,shift)(12,237)=511.880467
# dst(idx,shift)(13,237)=468.582676
# dst(idx,shift)(14,237)=496.410997
# dst(idx,shift)(15,237)=454.039928
# dst(idx,shift)(16,237)=441.064532
# dst(idx,shift)(17,237)=471.239406
# dst(idx,shift)(18,237)=560.023896
# dst(idx,shift)(19,237)=508.486742
# dst(idx,shift)(20,237)=557.528637
# dst(idx,shift)(21,237)=557.454409
# dst(idx,shift)(22,237)=517.725928
# dst(idx,shift)(23,237)=508.921404
# dst(idx,shift)(24,237)=459.558689
# dst(idx,shift)(25,237)=477.514642
# dst(idx,shift)(26,237)=494.253181
# dst(idx,shift)(27,237)=534.126311
# dst(idx,shift)(28,237)=557.181642
# dst(idx,shift)(29,237)=556.160326
# dst(idx,shift)(30,237)=564.938688
# dst(idx,shift)(31,237)=505.269277
# dst(idx,shift)(32,237)=453.770991
# dst(idx,shift)(33,237)=449.610180
# dst(idx,shift)(34,237)=447.590853
# dst(idx,shift)(35,237)=541.215614
# dst(idx,shift)(36,237)=546.518449
# dst(idx,shift)(37,237)=527.867526
# dst(idx,shift)(38,237)=541.369714
# dst(idx,shift)(39,237)=521.206567
# dst(idx,shift)(40,237)=481.399313
# dst(idx,shift)(41,237)=480.468104
# dst(idx,shift)(42,237)=487.615436
# dst(idx,shift)(43,237)=506.809795
# dst(idx,shift)(44,237)=493.208383
# dst(idx,shift)(45,237)=501.553366
# dst(idx,shift)(46,237)=522.643889
# dst(idx,shift)(47,237)=514.507886
# dst(idx,shift)(48,237)=566.209929
# dst(idx,shift)(49,237)=578.061877
# dst(idx,shift)(50,237)=535.138949
# dst(idx,shift)(51,237)=563.394779
# dst(idx,shift)(52,237)=544.159648
# dst(idx,shift)(53,237)=516.018471
# dst(idx,shift)(54,237)=505.927244
# dst(idx,shift)(55,237)=530.635366
# dst(idx,shift)(56,237)=566.013527
# dst(idx,shift)(57,237)=596.176445
# dst(idx,shift)(58,237)=579.196324
# dst(idx,shift)(59,237)=469.238073
# dst(idx,shift)(60,237)=545.565221
# dst(idx,shift)(61,237)=610.671237
# dst(idx,shift)(62,237)=622.396777
# dst(idx,shift)(63,237)=621.454799
# dst(idx,shift)(64,237)=561.407656
# dst(idx,shift)(65,237)=520.558901
# dst(idx,shift)(66,237)=499.132069
# dst(idx,shift)(67,237)=537.800790
# dst(idx,shift)(68,237)=537.410724
# dst(idx,shift)(69,237)=580.845822
# dst(idx,shift)(70,237)=553.113777
# dst(idx,shift)(71,237)=504.698357
# dst(idx,shift)(72,237)=604.632356
# dst(idx,shift)(73,237)=640.779872
# dst(idx,shift)(74,237)=667.765203
# dst(idx,shift)(75,237)=555.649198
# dst(idx,shift)(76,237)=620.687280
# dst(idx,shift)(77,237)=611.930586
# dst(idx,shift)(78,237)=657.948867
# dst(idx,shift)(79,237)=450.457954
# dst(idx,shift)(80,237)=525.128615
# dst(idx,shift)(81,237)=533.817132
# dst(idx,shift)(82,237)=569.129486
# dst(idx,shift)(83,237)=656.750573
# dst(idx,shift)(84,237)=615.045922
# dst(idx,shift)(85,237)=620.498725
# dst(idx,shift)(86,237)=583.280503
# dst(idx,shift)(87,237)=625.074393
# dst(idx,shift)(88,237)=672.802850
# dst(idx,shift)(89,237)=589.881725
# dst(idx,shift)(90,237)=580.771862
# dst(idx,shift)(91,237)=511.775261
# dst(idx,shift)(92,237)=457.576367
# dst(idx,shift)(93,237)=488.556328
# dst(idx,shift)(94,237)=494.052111
# dst(idx,shift)(95,237)=537.834459
# dst(idx,shift)(96,237)=569.456883
# dst(idx,shift)(97,237)=531.903386
# dst(idx,shift)(98,237)=626.204850
# dst(idx,shift)(99,237)=601.833403
# dst(idx,shift)(100,237)=593.526986
# dst(idx,shift)(101,237)=589.166763
# dst(idx,shift)(102,237)=485.756585
# dst(idx,shift)(103,237)=495.712889
# dst(idx,shift)(104,237)=449.835171
# dst(idx,shift)(105,237)=453.918942
# dst(idx,shift)(106,237)=444.166370
# dst(idx,shift)(107,237)=469.635263
# dst(idx,shift)(108,237)=525.592868
# dst(idx,shift)(109,237)=486.296520
# dst(idx,shift)(110,237)=436.537186
# dst(idx,shift)(111,237)=438.928331
# dst(idx,shift)(112,237)=468.799818
# dst(idx,shift)(113,237)=464.218499
# dst(idx,shift)(114,237)=542.939120
# dst(idx,shift)(115,237)=613.159380
# dst(idx,shift)(116,237)=608.530029
# dst(idx,shift)(117,237)=584.727026
# dst(idx,shift)(118,237)=596.827712
# dst(idx,shift)(119,237)=399.872286
# dst(idx,shift)(120,237)=498.824283
# dst(idx,shift)(121,237)=527.087366
# dst(idx,shift)(122,237)=512.982240
# dst(idx,shift)(123,237)=527.720285
# dst(idx,shift)(124,237)=545.917403
# dst(idx,shift)(125,237)=626.828531
# dst(idx,shift)(126,237)=629.124645
# dst(idx,shift)(127,237)=525.089135
# dst(idx,shift)(128,237)=512.305216
# dst(idx,shift)(129,237)=537.233362
# dst(idx,shift)(130,237)=607.805416
# dst(idx,shift)(131,237)=614.325994
# dst(idx,shift)(132,237)=609.726428
# dst(idx,shift)(133,237)=632.455110
# dst(idx,shift)(134,237)=626.540943
# dst(idx,shift)(135,237)=541.978618
# dst(idx,shift)(136,237)=564.957904
# dst(idx,shift)(137,237)=586.187282
# dst(idx,shift)(138,237)=611.631381
# dst(idx,shift)(139,237)=575.297375
# dst(idx,shift)(140,237)=500.560539
# dst(idx,shift)(141,237)=524.385949
# dst(idx,shift)(142,237)=562.241750
# dst(idx,shift)(143,237)=564.550109
# dst(idx,shift)(144,237)=529.907680
# dst(idx,shift)(145,237)=511.299560
# dst(idx,shift)(146,237)=483.404890
# dst(idx,shift)(147,237)=475.594197
# dst(idx,shift)(148,237)=520.913921
# dst(idx,shift)(149,237)=570.214597
# dst(idx,shift)(150,237)=615.672930
# dst(idx,shift)(151,237)=585.560483
# dst(idx,shift)(152,237)=549.715479
# dst(idx,shift)(153,237)=530.333925
# dst(idx,shift)(154,237)=584.706944
# dst(idx,shift)(155,237)=588.438712
# dst(idx,shift)(156,237)=538.365888
# dst(idx,shift)(157,237)=489.723311
# dst(idx,shift)(158,237)=523.336648
# dst(idx,shift)(159,237)=622.336137
# dst(idx,shift)(160,237)=565.129843
# dst(idx,shift)(161,237)=476.596745
# dst(idx,shift)(162,237)=555.999721
# dst(idx,shift)(163,237)=638.646236
# dst(idx,shift)(164,237)=561.938932
# dst(idx,shift)(165,237)=515.351064
# dst(idx,shift)(166,237)=549.375166
# dst(idx,shift)(167,237)=569.265609
# dst(idx,shift)(168,237)=563.866925
# dst(idx,shift)(169,237)=553.247165
# dst(idx,shift)(170,237)=527.722324
# dst(idx,shift)(171,237)=510.949127
# dst(idx,shift)(172,237)=633.143008
# dst(idx,shift)(173,237)=611.590718
# dst(idx,shift)(174,237)=531.598815
# dst(idx,shift)(175,237)=482.610865
# dst(idx,shift)(176,237)=469.869548
# dst(idx,shift)(177,237)=553.078399
# dst(idx,shift)(178,237)=528.611131
# dst(idx,shift)(179,237)=509.727701
# dst(idx,shift)(180,237)=513.778664
# dst(idx,shift)(181,237)=607.233152
# dst(idx,shift)(182,237)=595.935390
# dst(idx,shift)(183,237)=600.592206
# dst(idx,shift)(184,237)=559.839044
# dst(idx,shift)(185,237)=528.650407
# dst(idx,shift)(186,237)=623.395064
# dst(idx,shift)(187,237)=600.869277
# dst(idx,shift)(188,237)=583.418796
# dst(idx,shift)(189,237)=491.077362
# dst(idx,shift)(190,237)=459.213401
# dst(idx,shift)(191,237)=449.776675
# dst(idx,shift)(192,237)=491.101743
# dst(idx,shift)(193,237)=488.670228
# dst(idx,shift)(194,237)=576.484981
# dst(idx,shift)(195,237)=565.282999
# dst(idx,shift)(196,237)=556.847704
# dst(idx,shift)(197,237)=558.208554
# dst(idx,shift)(198,237)=535.598693
# dst(idx,shift)(199,237)=512.134528
# dst(idx,shift)(200,237)=529.013194
# dst(idx,shift)(201,237)=558.473987
# dst(idx,shift)(202,237)=539.971112
# dst(idx,shift)(203,237)=497.357518
# dst(idx,shift)(204,237)=575.509749
# dst(idx,shift)(205,237)=516.359900
# dst(idx,shift)(206,237)=586.249780
# dst(idx,shift)(207,237)=596.730905
# dst(idx,shift)(208,237)=600.215887
# dst(idx,shift)(209,237)=627.474081
# dst(idx,shift)(210,237)=618.358143
# dst(idx,shift)(211,237)=503.156226
# dst(idx,shift)(212,237)=496.363896
# dst(idx,shift)(213,237)=502.047644
# dst(idx,shift)(214,237)=450.674716
# dst(idx,shift)(215,237)=416.676495
# dst(idx,shift)(216,237)=411.038976
# dst(idx,shift)(217,237)=521.957278
# dst(idx,shift)(218,237)=514.179951
# dst(idx,shift)(219,237)=503.783828
# dst(idx,shift)(220,237)=425.297058
# dst(idx,shift)(221,237)=434.868474
# dst(idx,shift)(222,237)=441.402059
# dst(idx,shift)(223,237)=496.510405
# dst(idx,shift)(224,237)=501.269303
# dst(idx,shift)(225,237)=499.667355
# dst(idx,shift)(226,237)=510.975517
# dst(idx,shift)(227,237)=488.859939
# dst(idx,shift)(228,237)=471.027760
# dst(idx,shift)(229,237)=453.145448
# dst(idx,shift)(230,237)=549.271322
# dst(idx,shift)(231,237)=561.476384
# dst(idx,shift)(232,237)=598.703571
# dst(idx,shift)(233,237)=616.113012
# dst(idx,shift)(234,237)=646.648310
# dst(idx,shift)(235,237)=662.577865
# dst(idx,shift)(236,237)=643.137152
# dst(idx,shift)(237,237)=555.817467

# %%
# visualize
import seaborn as sns
import matplotlib.pyplot as plt

# %matplotlib inline
fig_size = [10,10]
plt.rcParams["figure.figsize"] = fig_size
plt.axis('equal')
ax = sns.heatmap(dst,
                 xticklabels=2,
                 yticklabels=2)
ax.set_xlabel('Shift')
ax.set_ylabel('Image Index')
ax.set_title('Distance Matrix')
plt.show()

# %% [markdown]
# ### 3. analyse the feature maps

# %%
print('Min, Max and Mean of Distances:')
print(np.min(dst), np.max(dst), np.average(dst))
lower, higher = np.min(dst), np.max(dst)

dst_t, dst_f = dst[:,0], dst[:,1:]
#print(dst_t.shape, dst_f.shape)
print('Min, Max and Mean of paired images:', np.min(dst_t), np.max(dst_t), np.mean(dst_t))
print('Min, Max and Mean of unpaired images:', np.min(dst_f), np.max(dst_f), np.mean(dst_f))

print('Sorted distance of paired images:')
print(np.sort(dst_t))

print('First n sorted distance of unpaired images:')
print(np.sort(dst_f.flatten())[:n])
# Out:
# Min, Max and Mean of Distances:
# 308.69242040508385 1083.2340104148213 563.1597499312354
# Min, Max and Mean of paired images: 308.69242040508385 991.0298638473591 498.5740834054776
# Min, Max and Mean of unpaired images: 377.92697783196604 1083.2340104148213 563.4322632921036
# Sorted distance of paired images:
# [308.69242041 315.85148092 357.42560279 361.84390571 367.29753812
#  367.86529604 376.79148329 380.178424   387.50141697 389.08328363
#  390.27192254 393.29977207 393.85328343 398.47247607 401.59964152
#  404.37283309 406.19175956 410.42602801 410.809367   412.9148928
#  413.27085962 413.64223374 415.9760338  419.40203813 419.94506146
#  420.5000564  420.54800634 420.69033719 422.03649812 422.49617645
#  422.70771619 423.67803089 423.73657867 425.05441135 425.7902412
#  426.18198767 426.6859559  427.41676598 427.99875284 428.11117104
#  428.87994752 429.29253149 429.61177551 430.19941139 431.50087038
#  432.1464989  432.29298701 432.29945372 432.43139571 432.49218584
#  433.05671352 433.37172376 435.03086625 435.0523299  435.3742824
#  436.23442512 436.65595704 437.85751169 438.67282823 438.76093775
#  439.22819599 440.75220388 441.36491495 442.22980744 443.17729507
#  443.28705657 446.85851948 447.56253529 447.58689486 450.48963031
#  451.42010708 451.56587101 451.66556694 454.6192712  455.55426114
#  456.53632136 457.46724988 458.11643836 459.52397745 460.36697096
#  461.49866185 462.27344058 463.98460567 464.01348737 464.92024915
#  465.93236585 466.15279265 467.01347196 467.15827336 467.25539699
#  467.38281038 467.87807602 468.10104227 468.71412622 469.00398762
#  469.07282357 470.04436643 472.04359397 472.72430009 475.07861379
#  476.43660918 476.46676306 476.47867852 476.66293091 476.97947555
#  477.75037887 478.05963322 479.29710586 480.74967523 480.75196557
#  481.14756772 481.34280434 481.95095446 482.49459463 482.94852218
#  483.15479155 483.32505575 483.59400766 485.26344823 486.44994355
#  487.75288697 487.85804445 488.55900139 489.17856044 489.65483063
#  489.82989265 490.30262183 490.53801121 495.09617016 495.25816738
#  495.72028528 497.23713585 497.99239739 498.58985521 498.97334875
#  501.13726231 501.65161225 502.74947398 503.24612295 504.47527413
#  504.96654896 507.52183902 508.12567524 509.24527266 509.54227313
#  510.38805027 510.71426692 513.51146377 513.63439457 516.70725676
#  517.06389643 517.44496465 517.44715189 518.43928253 519.54893491
#  520.62695602 520.97024471 521.40092641 522.49835166 523.89848702
#  524.56590025 525.56137063 525.70540837 525.75231743 527.59449474
#  529.17351507 530.31260925 530.87102352 531.01675942 533.31634719
#  533.6555647  534.34153724 538.02973676 538.27146097 540.29230929
#  540.50638002 541.90701011 546.13456848 546.69285461 547.69710229
#  547.96305929 548.24961167 549.05670086 550.33671006 555.9191528
#  556.17416131 557.92367767 558.74633707 559.29230489 559.58838908
#  562.08502608 562.46040222 565.08288908 567.81653185 567.94118631
#  568.39358685 568.79251752 569.05545612 569.9500632  571.11000532
#  572.09922179 572.45342318 573.51442057 575.72535004 575.96309375
#  579.85095124 585.58655452 585.89660834 586.73621445 587.03500536
#  592.19021127 592.79586662 592.80270233 592.89307449 593.27973581
#  596.00991111 596.35964561 598.92995148 600.84843519 601.2633196
#  602.3260238  603.43384671 607.033908   607.55910506 614.19791768
#  614.37924869 614.4229713  630.16514778 632.26812254 640.88530564
#  649.69084512 650.21925161 667.61422083 667.76090836 703.99626875
#  744.07611775 837.75499282 991.02986385]
# First n sorted distance of unpaired images:
# [377.92697783 384.31888858 387.31436264 387.34264569 389.10681789
#  389.23358245 389.40636146 389.43295077 390.35646661 391.02451756
#  391.60573489 392.72411589 393.33842072 394.2514706  394.36258481
#  394.53641988 395.49928998 396.12991859 396.20372117 397.43336997
#  397.75824746 399.35004485 399.43263866 399.60549406 399.7084783
#  399.83633604 399.87228558 401.1022385  401.17253655 401.43340081
#  401.82309367 401.857132   401.95944589 402.48489788 402.65464447
#  402.6948555  403.38249607 403.47854323 403.6304088  403.68659041
#  404.18993696 404.22269994 404.51936583 404.88890693 404.92688947
#  405.49539833 405.54241507 405.84373391 406.17719511 406.19909571
#  406.31885877 406.41407288 406.60658737 406.66975817 407.20703084
#  407.49511079 407.78234876 407.8129682  408.0597608  408.11345508
#  408.20804502 408.33739057 408.41083407 408.82113276 409.07477447
#  409.27469583 409.35152369 409.70116334 410.03046939 410.11479071
#  410.28071554 410.48783748 410.69422408 410.72198141 411.03897586
#  411.08689711 411.16200319 411.58697061 411.6732422  411.69807748
#  411.71729581 411.96055678 412.08852719 412.16760518 412.24842552
#  412.57750976 412.62357245 412.66311317 412.72152535 413.17590326
#  413.40191235 413.51341407 413.55597247 413.79551949 413.86039078
#  413.94281304 414.3846469  414.42096544 414.44549148 414.59230456
#  414.6559407  415.1560645  415.19238592 415.34297181 415.45798169
#  415.59736448 416.22409493 416.55775406 416.67649492 416.88458796
#  416.89933796 416.95806891 417.52961478 417.85863285 417.88362462
#  418.1945041  418.39114604 418.74081339 418.88226225 419.07107251
#  419.15057514 419.15495354 419.22251154 419.6292091  419.7707096
#  419.78572433 419.83714117 419.84867284 419.91672951 419.91877964
#  419.96716103 420.23600626 420.25838638 420.31985988 420.43994968
#  420.46585042 420.50269443 420.58684639 420.58799745 420.73500141
#  420.84468219 420.88674946 420.91249162 421.19092063 421.37829654
#  421.43935748 421.46196918 421.7857464  421.83205792 422.0306331
#  422.06655795 422.23777218 422.43239229 422.47326094 422.51659165
#  422.64403529 422.70249333 422.82975872 423.09842687 423.15837686
#  423.3055501  423.31724222 423.52547136 423.607357   423.89082307
#  423.95012424 424.02051554 424.03044626 424.15035375 424.56080833
#  424.60486242 424.60503184 424.66388223 424.74827044 424.77959346
#  424.81827294 424.89600161 424.97106893 425.00735348 425.01407254
#  425.04115073 425.05681564 425.28232628 425.29705802 425.44168262
#  425.45800996 425.47297784 425.54073302 425.55424605 425.71393806
#  425.87006824 425.96074948 425.98687703 426.27737651 426.38152793
#  426.38340644 426.40390664 426.46387111 426.62281097 426.70168548
#  426.74459269 426.8083654  426.93917763 427.09221228 427.13763178
#  427.17995826 427.25389003 427.25968913 427.28712663 427.33509559
#  427.41656863 427.50346693 427.59568418 427.73704635 427.80760284
#  427.82501457 427.8266223  427.83531856 427.89098223 427.89335491
#  427.89387448 427.95911013 427.97386747 428.08318777 428.11313993
#  428.13789656 428.23498621 428.50105793 428.52266673 428.57836052
#  428.74157184 428.75150754 428.75742335 428.7930594  428.8781002
#  429.01153294 429.09477607 429.11702496]

# %%
def predict(dst, threshold):
    return (dst <= threshold).astype(np.int)
def ground_truth(dst):
    n = dst.shape[0]
    gt = np.zeros((n,n)).astype(np.int)
    gt[:,0] = 1
    return gt
def confusion_matrix(pred, gt):
    n = gt.shape[0]
    TP = np.sum(gt[:,0] == pred[:,0])
    FN = np.sum(gt[:,0] != pred[:,0])
    TN = np.sum(gt[:,1:] == pred[:,1:])
    FP = np.sum(gt[:,1:] != pred[:,1:])
    TPR=TP/(TP+FN)
    FPR=FP/(FP+TN)
    ACC = (TP+TN)/(TP+TN+FP+FN)
    precision = TP/(TP+FP)
    recall = TP/(TP+FN)
    F1 = 2*precision*recall/(precision+recall)
    return TP,FP,TN,FN, TPR,FPR, ACC,precision,recall,F1

threshold = 500
pred = predict(dst, threshold)
gt = ground_truth(dst)

print("TP, FP, TN, FN, TPR, FPR, Accuracy, Precision, Recall, F1:")
print(confusion_matrix(pred, gt))
#%matplotlib inline
plt.axis('equal')
ax = sns.heatmap(pred,
                 xticklabels=2,
                 yticklabels=2)
ax.set_xlabel('Shift')
ax.set_ylabel('Image Index')
ax.set_title('Prediction Matrix')
plt.show()
# Out:
# TP, FP, TN, FN, TPR, FPR, Accuracy, Precision, Recall, F1:
# (135, 8888, 47518, 103, 0.5672268907563025, 0.1575718895152998, 0.8412718028387826, 0.014961764379917987, 0.5672268907563025, 0.029154518950437316)

# %%
# Draw ROC curve
np.seterr(divide='ignore',invalid='ignore')
ROC_x, ROC_y = [0], [0]
for threshold in range(int(lower),int(higher)+1):
    pred = predict(dst, threshold)
    gt = ground_truth(dst)
    conf_mat = confusion_matrix(pred, gt)
    x, y = conf_mat[5], conf_mat[4] # x: FPR, y: TPR
    ROC_x.append(x)
    ROC_y.append(y)
ROC_x.append(1)
ROC_y.append(1)
#%matplotlib inline
plt.plot(ROC_x, ROC_y)
plt.xlabel('FPR')
plt.ylabel('TPR')
plt.axis('equal')
plt.show()
